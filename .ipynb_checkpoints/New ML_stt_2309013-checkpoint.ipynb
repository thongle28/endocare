# %%
import sources.logins as lg
from sqlite3 import connect
import sources.parts_list_0802 as pl
import pandas as pd
from datetime import datetime as dt
import xlwings as xw

# %%
conn = connect('quotation.db')

# %%
sr = pl.summary_report()
task = sr.task_review(conn)
# Out:
#     Task  Receive  Repair  Ship
# 0    HCM        2       4     6
# 1  Hanoi        4       3    19

# %%
# copy full_file to destination folder
import shutil
import pathlib
import os
def copy_selected_file(des_folder,file_name):

#     des_folder = 'files'
    ans = str(input(f'Default folder "{des_folder}"(Blank),root or change to folder:'))
    path = pathlib.Path().absolute()
    if ans =='root': des_folder = ''
    elif ans !='': des_folder = ans
    des_path = os.path.join(path,des_folder)
    print(des_path)
    shutil.copy(file_name,os.path.join(des_path,file_name.split('\\')[-1]))
    
    print(f'Copy file name {file_name}  to  {des_path} completed')

# %%
#filter HCM
location = 'HCM'

print('Receive')
list_task = ['Create','Receive']

a_table = task[(task['location']==location)&(task['REPAIR_STATUS'].isin(list_task))]
for sn in a_table['SERIAL_NO']:
    print(sn)
display(a_table.drop(['repair_id','Start Time','End Time','location'],axis=1))

print('Under repair')
list_task = ['Inspection','Authorization']
a_table = task[(task['location']==location)&(task['REPAIR_STATUS'].isin(list_task))]

for sn in a_table['SERIAL_NO']:
    print(sn)
display(a_table.drop(['location','repair_id'],axis=1))

# QC and shipout
print('QC and Ship out')
list_task = ['Repair','QC']
a_table = task[(task['location']==location)&(task['REPAIR_STATUS'].isin(list_task))]

for sn in a_table['SERIAL_NO']:
    print(sn)
display(a_table.drop(['location','repair_id'],axis=1))
# Out:
# Receive
# 2C730K036
# 2G391K487
# 1C642K347
#           RMA No.                                      CUSTOMER_NAME  \
# 0  FMSV2023090009  No. 91 Endoscopy-Gastrointestinal-GI Scaning T...
# 1  FMSV2023090015                                FTYO - Loaner Asset
# 2  FMSV2023090016                         FUJIFILM Vietnam Co., Ltd.
#
#           MODEL  SERIAL_NO                     Receive REPAIR_STATUS  \
# 0  EC-760ZP-V/M  2C730K036                        None        Create
# 1      EG-600WR  2G391K487  2023-09-08 15:01:08.387000       Receive
# 2     EC-530WI3  1C642K347  2023-09-08 15:01:15.668000       Receive
#
#             update_user
# 0  Tran Minh Sang (HCM)
# 1        Le Quang Thong
# 2        Le Quang Thong
# Under repair
# 6G402K254
# 2G402K285
# 3C309K057
# 1G391K563
# 1G391K985
#           RMA No.                 CUSTOMER_NAME      MODEL  SERIAL_NO  \
# 3  FMSV2023080036    FUJIFILM Vietnam Co., Ltd.    EG-760R  6G402K254
# 4  FMSV2023060042             Hoang Long Clinic    EG-760R  2G402K285
# 5  FMSV2023080088  245 Clinic - Dr.Cuong Clinic  EC-250WL5  3C309K057
# 6  FMSV2023060045             Hoang Long Clinic   EG-600WR  1G391K563
# 7  FMSV2023060046             Hoang Long Clinic   EG-600WR  1G391K985
#
#                Receive           Start Time End Time  REPAIR_STATUS  \
# 3  2023-08-18 16:55:32                 None     None  Authorization
# 4  2023-06-19 16:20:36  2023-09-07 08:56:55     None  Authorization
# 5  2023-08-23 12:07:21  2023-09-07 12:11:09     None  Authorization
# 6  2023-06-19 16:23:54  2023-09-08 08:28:19     None  Authorization
# 7  2023-06-19 16:24:49  2023-09-08 08:31:30     None  Authorization
#
#       update_user
# 3  Le Quang Thong
# 4     Nguyen Thai
# 5     Nguyen Thai
# 6           hoang
# 7           hoang
# QC and Ship out
# 7G361K162
# 7G361K177
# 7G361K163
# 5C730K017
# 1C692K655
# 1C643K392
#            RMA No.                                      CUSTOMER_NAME  \
# 8   FMSV2023080044                         Dong Thap General Hospital
# 9   FMSV2023080041                         Dong Thap General Hospital
# 10  FMSV2023080043                         Dong Thap General Hospital
# 11  FMSV2023080059  No. 91 Endoscopy-Gastrointestinal-GI Scaning T...
# 12  FMSV2023080098                                         HCAP asset
# 13  FMSV2023080090                              Tay Nguyen University
#
#            MODEL  SERIAL_NO              Receive           Start Time  \
# 8       EG-530WR  7G361K162  2023-08-14 15:52:50  2023-08-18 09:45:07
# 9       EG-530WR  7G361K177  2023-08-11 16:26:30  2023-08-11 14:28:48
# 10      EG-530WR  7G361K163  2023-08-11 16:33:47  2023-08-18 08:55:26
# 11  EC-760ZP-V/M  5C730K017  2023-08-17 15:47:04  2023-08-30 16:52:08
# 12      EC-600WI  1C692K655  2023-08-30 18:52:28  2023-08-30 17:27:31
# 13     EC-530WL3  1C643K392  2023-08-30 19:09:33  2023-08-30 17:11:06
#
#                End Time REPAIR_STATUS     update_user
# 8   2023-08-24 08:44:39        Repair           hoang
# 9   2023-08-14 10:28:04            QC  Le Quang Thong
# 10  2023-08-22 16:35:17            QC     Nguyen Thai
# 11  2023-09-05 12:59:01            QC     Nguyen Thai
# 12  2023-09-06 08:23:30            QC     Nguyen Thai
# 13  2023-09-06 11:04:15            QC     Nguyen Thai

# %%
src_key = '''FMSV2023080052
'''

q = f'''
        SELECT [rma no.],customer_name,model,serial_no,[customer request],[defect note],repair_status
        FROM consolidated c
        WHERE UPPER([rma no.]) = '{src_key.strip().upper()}' OR UPPER([serial_no]) = '{src_key.strip().upper()}'
    '''
pd.read_sql(q,conn)

# %%
# new job no empty
q = f'''
        SELECT DISTINCT
                c.[rma no.],cu.customer_type,customer_name,cu.dealer,e.location,
                c.[create] as [Create Date],c.[Date Installed] AS [Installed Date],
                c.Model,c.Serial_no as Serial,sc.type,sc.mo,
                c.warranty_end_date as [Warranty End],c.recieve_date as [Received Date],
                c.in_inspect_date as [Inspection Date],c.[repair size] as [Size],c.[update user] as PIC,
                CASE
                    WHEN sc.status IS NULL THEN c.repair_status
                    ELSE sc.status || c.repair_status END AS [Status]
        
        FROM (((consolidated c
             LEFT JOIN pf_code pf on c.[rma no.] = pf.[rma no.])
             LEFT JOIN customerS cu ON c.[customer_code] = cu.[No.])
             LEFT JOIN engineers e ON c.[update user] = e.exfm_code)
             LEFT JOIN scopes sc ON c.model = sc.model
        WHERE c.[rma no.] > (select max(rma) from new_ml)
        
        ORDER BY c.[rma no.]
            
    '''
newjob = pd.read_sql(q,conn)
print(len(newjob))
newjob
# Out:
# 18
#            RMA No. customer_type  \
# 0   FMSV2023090001          None
# 1   FMSV2023090002       Private
# 2   FMSV2023090003       Private
# 3   FMSV2023090004    Government
# 4   FMSV2023090005    Government
# 5   FMSV2023090006       Private
# 6   FMSV2023090007       Private
# 7   FMSV2023090008    Government
# 8   FMSV2023090009       Private
# 9   FMSV2023090010      FF asset
# 10  FMSV2023090011    Government
# 11  FMSV2023090012    Government
# 12  FMSV2023090013    Government
# 13  FMSV2023090014    Government
# 14  FMSV2023090015      FF asset
# 15  FMSV2023090016      FF asset
# 16  FMSV2023090017       Private
# 17  FMSV2023090018       Private
#
#                                         CUSTOMER_NAME     dealer location  \
# 0                          Nam Can Tho Medical Center       None      HCM
# 1                                   Van Hanh Hospital        ETC      HCM
# 2                                         ETC Company        ETC     None
# 3                               103 Military Hospital       None    Hanoi
# 4                               103 Military Hospital       None    Hanoi
# 5                                   Hoang Long Clinic  Trang Thi    Hanoi
# 6                                   Hoang Long Clinic  Trang Thi    Hanoi
# 7                   Hanoi Medical University Hospital  Trang Thi    Hanoi
# 8   No. 91 Endoscopy-Gastrointestinal-GI Scaning T...        ETC      HCM
# 9                                 FTYO - Loaner Asset       None    Hanoi
# 10                                  Bach Mai Hospital  Trang Thi    Hanoi
# 11                                  Bach Mai Hospital  Trang Thi    Hanoi
# 12                                  Bach Mai Hospital  Trang Thi    Hanoi
# 13                                  Bach Mai Hospital  Trang Thi    Hanoi
# 14                                FTYO - Loaner Asset       None      HCM
# 15                         FUJIFILM Vietnam Co., Ltd.       None      HCM
# 16                             Hoan My Sai Gon Clinic        ETC      HCM
# 17                   Hoan My Sai Gon Premier Hospital        ETC      HCM
#
#             Create Date       Installed Date         MODEL     Serial  \
# 0   2023-09-05 00:00:00  2022-07-20 00:00:00     EC-530WL3  7C643K451
# 1   2023-09-05 00:00:00  2023-08-15 00:00:00     EC-530WL3  KC643K396
# 2   2023-09-05 00:00:00  2023-02-06 00:00:00       EP-6000  2V696K388
# 3   2023-09-05 00:00:00  2019-02-21 00:00:00      EC-600WI  3C692K105
# 4   2023-09-05 00:00:00  2019-02-21 00:00:00      EG-600WR  5G391K105
# 5   2023-09-05 00:00:00                 None       EG-760R  1G402K527
# 6   2023-09-05 00:00:00  2017-01-09 00:00:00       EG-760R  1G402K290
# 7   2023-09-07 00:00:00                 None     VP-4450HD  3V567K003
# 8   2023-09-08 00:00:00  2018-09-01 00:00:00  EC-760ZP-V/M  2C730K036
# 9   2023-09-08 00:00:00  2019-02-12 00:00:00     ED-530XT8  3D103L053
# 10  2023-09-08 00:00:00  2023-08-02 00:00:00      EG-600WR  KG391K536
# 11  2023-09-08 00:00:00  2021-08-06 00:00:00      EG-600WR  8G391K377
# 12  2023-09-08 00:00:00  2021-11-20 00:00:00      EC-600WI  6C692K137
# 13  2023-09-08 00:00:00  2021-02-23 00:00:00      EC-600WI  5C692K022
# 14  2023-09-08 00:00:00                 None      EG-600WR  2G391K487
# 15  2023-09-08 00:00:00  2018-06-08 00:00:00     EC-530WI3  1C642K347
# 16  2023-09-08 00:00:00  2016-05-25 00:00:00     EC-250WL5  1C309K073
# 17  2023-09-08 00:00:00  2019-10-05 00:00:00     EC-530WL3  5C643K346
#
#          Type    mo         Warranty End               Received Date  \
# 0      Colono   530  2023-07-20 00:00:00         2023-09-05 14:20:43
# 1      Colono   530  2024-08-15 00:00:00         2023-09-05 14:54:13
# 2   Processor  6000  2024-02-06 00:00:00         2023-09-05 15:40:28
# 3      Colono   600  2020-02-21 00:00:00         2023-09-05 17:30:07
# 4      Gastro   600  2020-02-21 00:00:00         2023-09-05 17:31:22
# 5      Gastro   760  2018-10-20 00:00:00         2023-09-05 18:02:03
# 6      Gastro   760  2018-01-09 00:00:00         2023-09-05 18:02:55
# 7   Processor  4450                 None         2023-09-07 17:20:24
# 8      Colono   760  2019-09-01 00:00:00                        None
# 9   Duo Scope   530                 None  2023-09-08 13:49:57.992000
# 10     Gastro   600  2024-08-02 00:00:00         2023-09-08 13:56:54
# 11     Gastro   600  2022-08-12 00:00:00  2023-09-08 13:57:42.669000
# 12     Colono   600  2022-11-20 00:00:00  2023-09-08 13:58:24.209000
# 13     Colono   600  2022-03-01 00:00:00  2023-09-08 13:59:05.849000
# 14     Gastro   600                 None  2023-09-08 15:01:08.387000
# 15     Colono   530                 None  2023-09-08 15:01:15.668000
# 16     Colono   250  2017-05-25 00:00:00         2023-09-08 15:08:45
# 17     Colono   530  2020-10-05 00:00:00         2023-09-08 15:17:31
#
#         Inspection Date   Size       PIC         Status
# 0   2023-09-05 14:51:06  Major    Nguyen     Inspection
# 1   2023-09-05 14:57:45  Major    Nguyen     Inspection
# 2   2023-09-06 17:57:13  Other    jasper  LP/Inspection
# 3   2023-09-07 12:52:40  Major     thang     Inspection
# 4   2023-09-07 13:04:54  Major  FFAP0070     Inspection
# 5   2023-09-07 18:35:02  Minor  FFAP0062  Authorization
# 6   2023-09-11 12:45:17  Major  FFAP0070     Inspection
# 7   2023-09-07 17:28:01  Other     thang      LP/Repair
# 8                  None   None      sang         Create
# 9                  None   None  tranminh        Receive
# 10  2023-09-11 13:34:49  Major  FFAP0070     Inspection
# 11                 None   None  tranminh        Receive
# 12                 None   None  tranminh        Receive
# 13                 None   None  tranminh        Receive
# 14                 None   None   thongle        Receive
# 15                 None   None   thongle        Receive
# 16  2023-09-08 15:15:34  Major   thongle     Inspection
# 17  2023-09-08 16:34:20  Major   thongle     Inspection

# %%
pd.read_sql('SELECT [old status] FROM new_ml',conn)
# Out:
#               Old status
# 0     waiting for repair
# 1     waiting for repair
# 2       waiting for part
# 3    LP/waiting for part
# 4    LP/waiting for part
# ..                   ...
# 179     Completed repair
# 180             Received
# 181     Under inspection
# 182             Received
# 183             Received
#
# [184 rows x 1 columns]

# %%
# add new job into ML

m_list = pd.read_sql('SELECT * FROM new_ml',conn)
bb = pl.summary_report()
cur = conn.cursor()
for i in range(len(newjob)):
    rma = newjob.iloc[i]['RMA No.']
    issue = bb.issues(conn,rma)
    i_no = i + len(m_list) + 1
    for j in range(len(newjob.iloc[i])):
        if newjob.iloc[i][j] == None:newjob.iloc[i][j] =''
            
    cur.execute(f"""INSERT INTO new_ml(rma,cus_type,Customer,Dealer,Location,installed_date,
                                       model,sn,scope_type,model2,wty_end_date,receive,inspection,repair_size,issue,
                                       pic,[old status]) 
                    VALUES('{newjob.iloc[i]['RMA No.']}','{newjob.iloc[i]['customer_type']}',"{newjob.iloc[i]['CUSTOMER_NAME']}",
                    '{newjob.iloc[i]['dealer']}','{newjob.iloc[i]['location']}',
                    '{str(newjob.iloc[i]['Installed Date'])}','{newjob.iloc[i]['MODEL']}','{newjob.iloc[i]['Serial']}',
                    '{newjob.iloc[i]['Type']}','{newjob.iloc[i]['mo']}','{newjob.iloc[i]['Warranty End']}',
                    '{newjob.iloc[i]['Received Date']}','{str(newjob.iloc[i]['Inspection Date'])}','{newjob.iloc[i]['Size']}',
                    "{issue}","{newjob.iloc[i]['PIC']}","{newjob.iloc[i]['Status']}")
    """)

# save conn
conn.commit()
print('Done')
# Out:
# Done

# %%
q = '''select max([UPDATE_time]) AS max_update FROM new_ml'''
udt = pd.read_sql(q,conn)
update_time = udt['max_update'][0]
print(update_time)

# filter new update in consolidated 
cur = conn.cursor()
q = f'''

        SELECT c.[rma no.],c.customer_name,c.model,c.serial_no,
        
                c.recieve_date,c.[repair size],c.[update user],c.in_inspect_date,c.repair_status,c.[status info],
                c.[other id],c.last_update_time,c.approval,c.[repair user name],
                c.[update time]
        FROM consolidated c
        WHERE c.[update time] > '{update_time}'
        AND C.[rma no.] IN (SELECT rma FROM m_list)
        
        ORDER BY 1
        
    '''
update_job = pd.read_sql(q,conn)
print(len(update_job))
# update_job
# Out:
# 2023-08-31 19:09:30.360000
# 9

# %%
# update all
bb = pl.summary_report() # create issue
cur = conn.cursor()
m_list = pd.read_sql('SELECT * FROM new_ml',conn)
for i in range(len(update_job)):
# i = 0

    rma = update_job.iloc[i]['RMA No.']
    issue = bb.issues(conn,rma)
    print(issue)
    #replace none to empty
    for j in range(len(update_job.iloc[i])):
        if update_job.iloc[i][j] == None:update_job.iloc[i][j] =''

    # UPDATE GENERAL
    q = f""" UPDATE new_ml 
                SET receive = '{update_job.iloc[i]["RECIEVE_DATE"]}',
                inspection = '{update_job.iloc[i]['IN_INSPECT_DATE']}',
                exfm_status = '{update_job.iloc[i]['REPAIR_STATUS']}',
                approval = '{update_job.iloc[i]['Approval']}',
                repair_user = '{update_job.iloc[i]['Repair User Name']}',
                update_time = '{update_job.iloc[i]['Update Time']}',
                update_user = '{update_job.iloc[i]['Update User']}',
                exfm_info = '{update_job.iloc[i]['Status Info']}' 
                
                WHERE RMA = '{rma}'"""
    cur.execute(q)
    #update fixed item
    fixed_items = ['receive','report_id','inspection','repair_size']
    update_items = ['RECIEVE_DATE','Other ID','IN_INSPECT_DATE','Repair Size']
#     update_items[fixed_items.index('Report_ID')]       # compare each point
    
    for item in fixed_items:
        if str(m_list[m_list['rma']==rma][item])=='':
            cur.execute(f'''
                            UPDATE new_ml SET '{item}' = '{updatejob.iloc[i][update_items[fixed_items.index(item)]]}'
                            WHERE RMA = '{rma}'
                        ''')
            print(f'Update {rma}: {item} values {updatejob.iloc[i][update_items[fixed_items.index(item)]]}')
conn.commit()
# Out:
# DWA
# BSA
# DRY, BSA, FCT, DEC
# FCT, AWT
# FCT
# FCT
# BSA, AWT
# DWA
# DWA

# %%
# update empty status
bb = pl.summary_report() # create issue
cur = conn.cursor()
m_list = pd.read_sql('SELECT * FROM new_ml',conn)

q = f'''
        SELECT m.rma,m.customer,m.model,m.sn,C.[repair_status],c.[status info],m.exfm_status,m.exfm_info,
        c.approval,c.[update time],c.[update user],c.[repair user name],c.recieve_date,c.in_inspect_date,
        c.[repair size]
        
        FROM new_ml m
        LEFT JOIN consolidated c ON m.rma = c.[rma no.]
        
    '''
stt_info = pd.read_sql(q,conn)
display(stt_info)

for i in range(len(stt_info)):
# i = 0
#     print(i)
    rma = m_list.iloc[i]['rma']
    issue = bb.issues(conn,rma)
#     print(rma,issue)
    
    #replace none to empty
    for j in range(len(stt_info.iloc[i])):
        if stt_info.iloc[i][j] == None:stt_info.iloc[i][j] =''

    # UPDATE GENERAL
    cur.execute(f"""UPDATE new_ml SET issue = '{issue}',
    exfm_status = '{stt_info.iloc[i]['REPAIR_STATUS']}',
    exfm_info = '{stt_info.iloc[i]['Status Info']}',
    approval = '{stt_info.iloc[i]['Approval']}',
    update_time = '{stt_info.iloc[i]['Update Time']}',
    update_user = '{stt_info.iloc[i]['Update User']}',
    receive = '{stt_info.iloc[i]['RECIEVE_DATE']}',
    inspection = '{stt_info.iloc[i]['IN_INSPECT_DATE']}',
    repair_size = '{stt_info.iloc[i]['Repair Size']}'
    
    WHERE rma = '{rma}'""")
    
conn.commit()
print('Done')
# Out:
#                 rma                           customer         model  \
# 0    FMSV2023020019         FUJIFILM Vietnam Co., Ltd.  EC-760ZP-V/M
# 1    FMSV2023020022                FTYO - Loaner Asset  EC-760ZP-V/M
# 2    FMSV2023020034                  Hoang Long Clinic   EC-760R-V/I
# 3    FMSV2023020067  Hanoi Medical University Hospital     VP-4450HD
# 4    FMSV2023030060                  Hoang Long Clinic       VP-7000
# ..              ...                                ...           ...
# 197  FMSV2023090014                  Bach Mai Hospital      EC-600WI
# 198  FMSV2023090015                FTYO - Loaner Asset      EG-600WR
# 199  FMSV2023090016         FUJIFILM Vietnam Co., Ltd.     EC-530WI3
# 200  FMSV2023090017             Hoan My Sai Gon Clinic     EC-250WL5
# 201  FMSV2023090018   Hoan My Sai Gon Premier Hospital     EC-530WL3
#
#             sn REPAIR_STATUS                         Status Info exfm_status  \
# 0    2C730K027    Inspection                         PO Received  Inspection
# 1    2C730K032    Inspection                         PO Received  Inspection
# 2    1C728K180    Inspection              Parts Preparation (WH)  Inspection
# 3    2V567K684    Inspection                   Waiting for Parts  Inspection
# 4    2V644K028    Inspection                      Parts on Order  Inspection
# ..         ...           ...                                 ...         ...
# 197  5C692K022       Receive                                None        None
# 198  2G391K487       Receive                                None        None
# 199  1C642K347       Receive                                None        None
# 200  1C309K073    Inspection  Waiting for Next Process Available        None
# 201  5C643K346    Inspection  Waiting for Next Process Available        None
#
#                   exfm_info Approval                 Update Time Update User  \
# 0               PO Received     None  2023-08-14 12:49:42.137000     thongle
# 1               PO Received     None  2023-08-14 12:49:53.215000     thongle
# 2    Parts Preparation (WH)     None  2023-08-18 11:02:42.937000      Nguyen
# 3         Waiting for Parts     None  2023-07-11 10:55:22.985000     thongle
# 4            Parts on Order     None  2023-08-09 11:49:51.353000       thang
# ..                      ...      ...                         ...         ...
# 197                    None     None  2023-09-08 13:59:05.849000    tranminh
# 198                    None     None  2023-09-08 15:01:08.387000     thongle
# 199                    None     None  2023-09-08 15:01:15.668000     thongle
# 200                    None     None  2023-09-08 16:46:49.581000     thongle
# 201                    None     None  2023-09-08 16:46:33.122000     thongle
#
#     Repair User Name                RECIEVE_DATE      IN_INSPECT_DATE  \
# 0               None         2023-02-08 18:31:56  2023-02-13 17:33:19
# 1               None         2023-02-08 18:54:02  2023-02-14 12:09:53
# 2               None         2023-02-16 14:11:27  2023-02-23 16:11:49
# 3               None         2023-02-28 17:07:16  2023-03-02 12:18:44
# 4               None         2023-03-23 19:41:03  2023-03-31 12:26:02
# ..               ...                         ...                  ...
# 197             None  2023-09-08 13:59:05.849000                 None
# 198             None  2023-09-08 15:01:08.387000                 None
# 199             None  2023-09-08 15:01:15.668000                 None
# 200             None         2023-09-08 15:08:45  2023-09-08 15:15:34
# 201             None         2023-09-08 15:17:31  2023-09-08 16:34:20
#
#     Repair Size
# 0         Major
# 1         Major
# 2         Major
# 3         Other
# 4         Other
# ..          ...
# 197        None
# 198        None
# 199        None
# 200       Major
# 201       Major
#
# [202 rows x 15 columns]
# Done

# %%
#check no receive and inspection
q = '''
        SELECT rma,receive,inspection,
        c.[recieve_date],c.[in_inspect_date]
        
        FROM new_ml m
        LEFT JOIN consolidated c ON m.rma = c.[rma no.]
        WHERE (receive IS NULL OR inspection IS NULL)
        
    '''
pd.read_sql(q,conn)
# Out:
# Empty DataFrame
# Columns: [rma, receive, inspection, RECIEVE_DATE, IN_INSPECT_DATE]
# Index: []

# %%
#filter completed
q = '''
        SELECT  rma,customer,model, sn,repair_size,issue,pic,note,location,
            receive,quotation,confirmation,part_order_date, part_received_date,
            start_repair,qc_date,return_date 
        FROM new_ml 
        WHERE status LIKE '%Completed repair' 
        ORDER BY rma
'''
completed_list = pd.read_sql(q,conn)
completed_list

# %%
#delete job completed from new_ml
cur.execute('DELETE FROM new_ml WHERE status LIKE "%Completed repair"')
conn.commit()

# %%
q = '''
        SELECT * FROM new_ml
        WHERE exfm_status IS NULL
        
    '''
pd.read_sql(q,conn)

# %% [markdown]
# #####  Export

# %%
file_name = lg.file_select(folder_name = 'files', end_with = '.xlsm')
xw.Book(file_name)
# Out:
# ______________________________________________________________________
# |  No.|  File Name                               |  Modified Time    |
# |____________________________________________________________________|
# |  1  |  New ML_230830_165145.xlsm               |  04-Sep-23 11:38  |
# |  2  |  New ML_230904_120653.xlsm               |  04-Sep-23 12:14  |
# |  3  |  New ML_230906_104344.xlsm               |  07-Sep-23 11:14  |
# |  4  |  New ML_230910_214754.xlsm               |  10-Sep-23 21:47  |
# |____________________________________________________________________|
# Select file (Default 1): 3
# "New ML_230906_104344.xlsm" is selected
# <Book [New ML_230906_104344.xlsm]>

# %%
# final
q = '''SELECT * FROM new_ml'''
m_list_final = pd.read_sql(q,conn)
for i in range(len(m_list_final)):
    rma = m_list_final.iloc[i]['rma']
    issue = bb.issues(conn,rma)
    
    #replace none to empty
    for j in range(len(m_list_final.iloc[i])):
#         if m_list_final.iloc[i][j] == None: m_list_final.iloc[i][j] =''
        if m_list_final.iloc[i][j] == 'None': m_list_final.iloc[i][j] =''
           
m_list_final = m_list_final.drop(['TAT_receive','TAT_PO','TAT_PART'],axis=1)
dtmp = dt.now().strftime('%y%m%d')
file_name = f'ML_{dtmp}.xlsx'
m_list_final.to_excel(file_name,index = False)
xw.Book(file_name)
# Out:
# <Book [ML_230911.xlsx]>

# %%
# copy file from files folder to inspection
file = lg.file_select(folder_name='files',start_with='New ML')
# to destination folder

try:
    copy_selected_file(des_folder='New ML',file_name = file)
    print(f'Copy sucess file {file}')
except Exception as e:
    print(e)

# %%
# delete Master list in folder file
import os
import pathlib
path = pathlib.Path().absolute()
folder_name = 'files'
file_name = file.split('\\')[-1]
for file in os.listdir(folder_name):
    
    if 'New ML' in file and file_name not in file:
        print(f'deleted file {file}')
        os.remove(os.path.join(path,folder_name,file))
        
# delete file ML
for file in os.listdir():
    
    if 'ML_' in file and file_name not in file:
        print(f'deleted file {file}')
        os.remove(os.path.join(path,file))

for file in os.listdir('New ML'):
    
    if 'ML_' in file and file_name not in file:
        print(f'deleted file {file}')
        os.remove(os.path.join(path,file))

# %%
for file in os.listdir('New ML'):
    
    if 'ML_' in file and file_name not in file:
        print(f'deleted file {file}')
        os.remove(os.path.join(path,file))

# %%
# compare new ML and ExFM
q = '''
        SELECT [rma no.],customer_name, model, serial_no,repair_status,
        [update user],[update time],[status info]
        
        FROM consolidated
        WHERE [rma no.] NOT IN (SELECT rma FROM new_ml)
        
'''
gap = pd.read_sql(q,conn)
gap.to_excel('exfm_gap_230816.xlsx',index = False)
