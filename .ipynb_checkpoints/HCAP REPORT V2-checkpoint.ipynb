# %%
import pandas as pd
from sqlite3 import connect
import xlwings as xw
import numpy as np
from datetime import datetime as dt
import os
import pathlib
import sources.parts_list_0802 as pl

def working_day(start_date,end_date):
    try:
        res = np.busday_count(start_date.strftime('%Y-%m-%d'),
                          start_date.strftime('%Y-%m-%d'))
    except:
        res = np.busday_count(start_date,end_date)
    return res + 1 
# conn.create_function("WORKING_DAY",2,working_day)

conn = connect('history.db')

q = '''SELECT * FROM new_ml WHERE status  IS not "0] CLOSED"'''
new_ml = pd.read_sql(q,conn)
rma_list = tuple(new_ml['ExFM RMA#'])
print(len(rma_list),max(rma_list))
# Out:
# 307 FMSV2024010037

# %%
#priority receive, inspect, quote, confirm, part order, part receive
# new format combine with ML
# filter RMA 

q = f'''
        SELECT DISTINCT c.[rma no.] as [ExFM RMA#],
        CASE 
            WHEN m.receive IS NOT NULL THEN strftime('%Y-%m-%d',m.receive)
            ELSE strftime('%Y-%m-%d',recieve_date) END as [Receive],
        strftime('%Y-%m-%d',R.[start time]) as [Start Date],
        strftime('%Y-%m-%d',c.qc) as [End Date],
        '' as [Repair TAT],
        repair_status AS [Repair Status],c.approval,
        CASE
            WHEN repair_status IS 'Receive' THEN '1] RECEIVE'
            WHEN repair_status IS 'Inspection' THEN '2] INSPECTION'
            WHEN repair_status IS 'Parts Selection' THEN '3] PARTS SELECTION'
            WHEN repair_status IS 'Authorization'  AND c.approval IS 'Approval' 
                AND c.[Status Info] IS 'PO Received' THEN '4C] Approved Repair'
            
            WHEN repair_status IS 'Authorization'  AND r.[start time] IS NOT NULL THEN '5] REPAIR'
            WHEN repair_status IS 'Authorization'  AND c.approval IS NOT 'Approval' THEN '4B] Decline Repair'
            WHEN repair_status IS 'Authorization'  AND c.approval IS 'Approval' 
                AND (c.[Status Info] IS 'Waiting for Parts' OR c.[Status Info] IS 'Parts on Order') 
                THEN '4A] Waiting for Parts'

            WHEN repair_status IS 'Repair' THEN '5] REPAIR'
            WHEN repair_status IS 'QC' THEN '6] QC'
            WHEN repair_status IS 'Shipped' THEN '7] SHIPPED'
            WHEN repair_status IS 'Completed' THEN '0] CLOSED'
            
            ELSE repair_status END AS STATUS,
        c.[status info],strftime('%Y-%m-%d',c.[Due Date]) AS [Due Date],
        e.short_name AS Repairer,
        CASE
            WHEN m.location IS NOT NULL THEN m.location
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location, 
        
        customer_name AS [Customer Name],c.model,UPPER(serial_no) AS SN,c.[Date Installed],
        m.[information from customer],
        [defect note] AS [Problem Descript.],
        CASE
            WHEN c.approval IN ('Decline','Cancel','Transfer') THEN 'Return'
            ELSE c.[repair size] END AS repair_size,
        m.issue AS Issue,
        CASE 
            WHEN m.[inspect date] IS NOT NULL THEN strftime('%Y-%m-%d',m.[inspect date])
            ELSE strftime('%Y-%m-%d',c.in_inspect_date) END AS [Inspect Date],
        CASE 
            WHEN m.[quote date] IS NOT NULL THEN m.[quote date]
            ELSE strftime('%Y-%m-%d',[Part Select Date]) END AS [Quote Date],
        CASE
            WHEN m.[confirm date] IS NOT NULL THEN m.[confirm date]
            ELSE strftime('%Y-%m-%d',AUTHORIZED_DATE) END AS [Confirm Date],
        '' AS [PO TAT],
        m.[Part Order Date] AS [Part Order Date],
        m.[Part Receive Date] AS [Part Receive Date],
        '' [Parts TAT],
        '' AS [Total TAT],
        strftime('%Y-%m-%d',c.shipped) AS Shipped,c.[other id],c.[internal note],c.[Loaner Shp Note],
        CASE
            WHEN m.[repair size] IN ("Minor",'Other') THEN 200
            WHEN issue LIKE "%dry%" THEN 600
            WHEN issue LIKE "%cha%" OR issue LIKE "%LGB%" THEN 500
            WHEN issue LIKE "%FCT%" OR issue LIKE "%AWT%" OR issue LIKE "%DEC%" THEN 450
            WHEN issue LIKE "%BSA%" OR issue LIKE "%FSA" OR issue LIKE "%FSB" THEN 400
            ELSE 350 END AS [Service_Fee],
        m.[Quote Price (VND)],install.[group]
        
        FROM (((((((consolidated c
        LEFT JOIN repair_code r ON c.[rma no.] = r.[rma no.])
        LEFT JOIN new_ml m ON c.[rma no.] = m.[exfm rma#])
        
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name)
        LEFT JOIN install ON c.serial_no = install.[serial no.]
        
        WHERE 
            c.[rma no.] IN {rma_list}
            OR c.[rma no.] > '{max(rma_list)}'
        
        ORDER BY 1
    '''
            
        
try:
    hcap = pd.read_sql(q,conn)
    display(hcap)
except Exception as e:
    print(e)
# Out:
#            ExFM RMA#     Receive Start Date End Date Repair TAT  \
# 0     FMSV2023030069  2023-03-28       None     None
# 1     FMSV2023030079  2023-03-30       None     None
# 2     FMSV2023040070  2023-04-26       None     None
# 3    FMSV2023050045L  2023-06-13       None     None
# 4     FMSV2023050072  2023-05-29       None     None
# ..               ...         ...        ...      ...        ...
# 309   FMSV2024010040  2024-01-23       None     None
# 310   FMSV2024010041  2024-01-23       None     None
# 311   FMSV2024010042  2024-01-23       None     None
# 312   FMSV2024010043  2024-01-23       None     None
# 313   FMSV2024010044  2024-01-23       None     None
#
#        Repair Status  Approval                 STATUS  \
# 0      Authorization  Approval  4A] Waiting for Parts
# 1    Parts Selection      None     3] PARTS SELECTION
# 2      Authorization  Approval    4C] Approved Repair
# 3      Authorization  Approval    4C] Approved Repair
# 4      Authorization  Approval  4A] Waiting for Parts
# ..               ...       ...                    ...
# 309          Receive      None             1] RECEIVE
# 310          Receive      None             1] RECEIVE
# 311          Receive      None             1] RECEIVE
# 312          Receive      None             1] RECEIVE
# 313          Receive      None             1] RECEIVE
#
#                   Status Info    Due Date  ...    Part Receive Date Parts TAT  \
# 0              Parts on Order        None  ...                 None
# 1    Awating Contract billing  2024-01-30  ...                 None
# 2                 PO Received        None  ...  2023-12-27 00:00:00
# 3                 PO Received        None  ...  2023-12-27 00:00:00
# 4              Parts on Order        None  ...                 None
# ..                        ...         ...  ...                  ...       ...
# 309                      None        None  ...                 None
# 310                      None        None  ...                 None
# 311                      None        None  ...                 None
# 312                      None        None  ...                 None
# 313                      None        None  ...                 None
#
#     Total TAT Shipped Other ID  \
# 0                None    PO116
# 1                None     None
# 2                None    PO115
# 3                None    PO115
# 4                None     None
# ..        ...     ...      ...
# 309              None     None
# 310              None     None
# 311              None     None
# 312              None     None
# 313              None     None
#
#                                          Internal Note Loaner Shp Note  \
# 0                                                 None            SGA1
# 1                                                 None            None
# 2                                                 None            SGA2
# 3    Hoan My Sai Gon\r\ndrying by heating and vacuu...            SGA1
# 4    QC after loaner HNNA\r\nBlack spot's at 7o'clo...            None
# ..                                                 ...             ...
# 309                                               None            None
# 310                                               None            None
# 311                                               None            None
# 312                                               None            None
# 313                                               None            None
#
#     Service_Fee Quote Price (VND)      Group
# 0           500         226000000      SCOPE
# 1           200         268000000  PROCESSOR
# 2           500              None      SCOPE
# 3           600              None      SCOPE
# 4           600              None      SCOPE
# ..          ...               ...        ...
# 309         350              None  PROCESSOR
# 310         350              None      SCOPE
# 311         350              None      SCOPE
# 312         350              None      SCOPE
# 313         350              None      SCOPE
#
# [314 rows x 35 columns]

# %%
#calculate TAT

for i in range(len(hcap)):
    rma = hcap['ExFM RMA#'][i]
    issue = pl.summary_report().issues(conn,rma)
    # TAT repair
    if hcap['Start Date'][i] is not None and hcap['End Date'][i] is not None:
        hcap['Repair TAT'][i] = working_day(hcap['Start Date'][i],hcap['End Date'][i])
    # PO TAT
    if hcap['Quote Date'][i] is not None and hcap['Confirm Date'][i] is not None:
        try:
            hcap['PO TAT'][i] = working_day(hcap['Quote Date'][i],hcap['Confirm Date'][i])
        except:
#             print(f"{hcap['SN'][i]} failed PO TAT")
            pass
    # issue
    if hcap['Issue'][i] is None:
        hcap['Issue'][i] = issue
    if hcap['Repair Status'][i] != 'Completed':
        try:
            hcap['Total TAT'] = working_day(hcap['Receive'][i],dt.now().strftime('%Y-%m-%d'))
        except Exception as e:
            print(e,f"{hcap['SN'][i]}")
    else:
        if hcap['Shipped'][i] is not None:
            hcap['Total TAT'] = working_day(hcap['Receive'][i],hcap['Shipped'][i])
hcap
# Out:
# Cannot compute a business day count with a NaT (not-a-time) date 8G402K627
# Cannot compute a business day count with a NaT (not-a-time) date 8G402K627
#            ExFM RMA#     Receive  Start Date End Date Repair TAT  \
# 0     FMSV2023030069  2023-03-28        None     None
# 1     FMSV2023030079  2023-03-30        None     None
# 2     FMSV2023040070  2023-04-26        None     None
# 3    FMSV2023050045L  2023-06-13        None     None
# 4     FMSV2023050072  2023-05-29        None     None
# ..               ...         ...         ...      ...        ...
# 316   FMSV2024010033  2024-01-19  2024-01-19     None
# 317   FMSV2024010034  2024-01-19        None     None
# 318   FMSV2024010035  2024-01-19  2024-01-19     None
# 319   FMSV2024010036  2024-01-19        None     None
# 320   FMSV2024010037  2024-01-22        None     None
#
#        Repair Status  Approval                 STATUS  \
# 0      Authorization  Approval  4A] Waiting for Parts
# 1    Parts Selection      None     3] PARTS SELECTION
# 2      Authorization  Approval    4C] Approved Repair
# 3      Authorization  Approval    4C] Approved Repair
# 4      Authorization  Approval  4A] Waiting for Parts
# ..               ...       ...                    ...
# 316           Repair  Approval              5] REPAIR
# 317          Receive      None             1] RECEIVE
# 318           Repair  Approval              5] REPAIR
# 319          Receive      None             1] RECEIVE
# 320          Receive      None             1] RECEIVE
#
#                   Status Info    Due Date  ...    Part Receive Date Parts TAT  \
# 0              Parts on Order        None  ...                 None
# 1    Awating Contract billing  2024-01-30  ...                 None
# 2                 PO Received        None  ...  2023-12-27 00:00:00
# 3                 PO Received        None  ...  2023-12-27 00:00:00
# 4              Parts on Order        None  ...                 None
# ..                        ...         ...  ...                  ...       ...
# 316                      None        None  ...                 None
# 317                      None        None  ...                 None
# 318                      None        None  ...                 None
# 319                      None        None  ...                 None
# 320                      None        None  ...                 None
#
#     Total TAT Shipped Other ID  \
# 0           1    None    PO116
# 1           1    None     None
# 2           1    None    PO115
# 3           1    None    PO115
# 4           1    None     None
# ..        ...     ...      ...
# 316         1    None     None
# 317         1    None     None
# 318         1    None     None
# 319         1    None     None
# 320         1    None     None
#
#                                          Internal Note Loaner Shp Note  \
# 0                                                 None            SGA1
# 1                                                 None            None
# 2                                                 None            SGA2
# 3    Hoan My Sai Gon\r\ndrying by heating and vacuu...            SGA1
# 4    QC after loaner HNNA\r\nBlack spot's at 7o'clo...            None
# ..                                                 ...             ...
# 316                                               None            None
# 317                                               None            None
# 318                                               None            None
# 319                                               None            None
# 320                                               None            None
#
#     Service_Fee Quote Price (VND)      Group
# 0           500         226000000      SCOPE
# 1           200         268000000  PROCESSOR
# 2           500              None      SCOPE
# 3           600              None      SCOPE
# 4           600              None      SCOPE
# ..          ...               ...        ...
# 316         350              None      SCOPE
# 317         350              None      SCOPE
# 318         350              None  PROCESSOR
# 319         350              None      SCOPE
# 320         350              None      SCOPE
#
# [321 rows x 35 columns]
#            ExFM RMA#     Receive  Start Date End Date Repair TAT  \
# 0     FMSV2023030069  2023-03-28        None     None
# 1     FMSV2023030079  2023-03-30        None     None
# 2     FMSV2023040070  2023-04-26        None     None
# 3    FMSV2023050045L  2023-06-13        None     None
# 4     FMSV2023050072  2023-05-29        None     None
# ..               ...         ...         ...      ...        ...
# 316   FMSV2024010033  2024-01-19  2024-01-19     None
# 317   FMSV2024010034  2024-01-19        None     None
# 318   FMSV2024010035  2024-01-19  2024-01-19     None
# 319   FMSV2024010036  2024-01-19        None     None
# 320   FMSV2024010037  2024-01-22        None     None
#
#        Repair Status  Approval                 STATUS  \
# 0      Authorization  Approval  4A] Waiting for Parts
# 1    Parts Selection      None     3] PARTS SELECTION
# 2      Authorization  Approval    4C] Approved Repair
# 3      Authorization  Approval    4C] Approved Repair
# 4      Authorization  Approval  4A] Waiting for Parts
# ..               ...       ...                    ...
# 316           Repair  Approval              5] REPAIR
# 317          Receive      None             1] RECEIVE
# 318           Repair  Approval              5] REPAIR
# 319          Receive      None             1] RECEIVE
# 320          Receive      None             1] RECEIVE
#
#                   Status Info    Due Date  ...    Part Receive Date Parts TAT  \
# 0              Parts on Order        None  ...                 None
# 1    Awating Contract billing  2024-01-30  ...                 None
# 2                 PO Received        None  ...  2023-12-27 00:00:00
# 3                 PO Received        None  ...  2023-12-27 00:00:00
# 4              Parts on Order        None  ...                 None
# ..                        ...         ...  ...                  ...       ...
# 316                      None        None  ...                 None
# 317                      None        None  ...                 None
# 318                      None        None  ...                 None
# 319                      None        None  ...                 None
# 320                      None        None  ...                 None
#
#     Total TAT Shipped Other ID  \
# 0           1    None    PO116
# 1           1    None     None
# 2           1    None    PO115
# 3           1    None    PO115
# 4           1    None     None
# ..        ...     ...      ...
# 316         1    None     None
# 317         1    None     None
# 318         1    None     None
# 319         1    None     None
# 320         1    None     None
#
#                                          Internal Note Loaner Shp Note  \
# 0                                                 None            SGA1
# 1                                                 None            None
# 2                                                 None            SGA2
# 3    Hoan My Sai Gon\r\ndrying by heating and vacuu...            SGA1
# 4    QC after loaner HNNA\r\nBlack spot's at 7o'clo...            None
# ..                                                 ...             ...
# 316                                               None            None
# 317                                               None            None
# 318                                               None            None
# 319                                               None            None
# 320                                               None            None
#
#     Service_Fee Quote Price (VND)      Group
# 0           500         226000000      SCOPE
# 1           200         268000000  PROCESSOR
# 2           500              None      SCOPE
# 3           600              None      SCOPE
# 4           600              None      SCOPE
# ..          ...               ...        ...
# 316         350              None      SCOPE
# 317         350              None      SCOPE
# 318         350              None  PROCESSOR
# 319         350              None      SCOPE
# 320         350              None      SCOPE
#
# [321 rows x 35 columns]

# %%
today = dt.now().strftime('%y%m%d')
# today = '231019'
folder_name = 'inspection'
path = pathlib.Path().absolute()
file_name = f'FFVN-Repair_{today}.xlsx'
file_name = os.path.join(path,folder_name,file_name)
# hcap.to_excel(file_name,index = False)

with pd.ExcelWriter(file_name,date_format="YYYY-MM-DD",
    datetime_format="YYYY-MM-DD HH:MM:SS") as writer:
    hcap.to_excel(writer,index = False)

#OPEN FILE 
xw.Book(file_name)
# Out:
# <Book [FFVN-Repair_240124.xlsx]>

# %% [markdown]
# ### fy2023 1h

# %%
hcap.to_sql('hcap',conn,index=False,if_exists='replace')
# Out:
# 314

# %% [markdown]
# ### Receive

# %%
q = f'''
        SELECT [exfm rma#],[customer name],hcap.model,sn,receive,
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location
        
        FROM ((((hcap
        LEFT JOIN consolidated c ON hcap.[exfm rma#] = c.[rma no.])
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.shipped = ship.exfm_name
        
        WHERE [exfm rma#] > '{max(rma_list)}'
    '''
print(max(rma_list))
new_receive = pd.read_sql(q,conn)
new_receive
# Out:
# FMSV2024010037
#         ExFM RMA#                               Customer Name           MODEL  \
# 0  FMSV2024010038  Vietnam – Cuba Donghoi Friendship Hospital         EG-760R
# 1  FMSV2024010039                  FUJIFILM Vietnam Co., Ltd.        EG-530WR
# 2  FMSV2024010040                  FUJIFILM Vietnam Co., Ltd.  EPX-2500(230V)
# 3  FMSV2024010041            Hai Phong International Hospital       EG-250WR5
# 4  FMSV2024010042            Hai Phong International Hospital       EG-250WR5
# 5  FMSV2024010043                  FUJIFILM Vietnam Co., Ltd.        EC-530WI
# 6  FMSV2024010044                   Tra Vinh General Hospital       EC-250WL5
#
#           SN     Receive location
# 0  KG402K677  2024-01-23    Hanoi
# 1  4G361K141  2024-01-23    Hanoi
# 2  5V564D396  2024-01-23    Hanoi
# 3  2G202K044  2024-01-23    Hanoi
# 4  2G202K043  2024-01-23    Hanoi
# 5  1C603K041  2024-01-23    Hanoi
# 6  3C309K056  2024-01-23      HCM

# %% [markdown]
# ### Complete

# %%
# tracking
q= 'SELECT DISTINCT STATUS FROM new_ml'
pd.read_sql(q,conn)

# %%
# tracking
q = '''
        SELECT [ExFM RMA#] FROM new_ml 
        WHERE status IN ('1] RECEIVE','2] INSPECTION','3] PARTS SELECTION',
                        '4A] Waiting for Parts','4C] Approved Repair','5] REPAIR')
    '''
pending = pd.read_sql(q,conn)

#completed
q = f'''
        SELECT DISTINCT [customer name],model,sn,location,repair_size,issue,status,[end date],shipped,[exfm rma#]
        
        FROM hcap
        WHERE ([exfm rma#] IN {tuple(pending['ExFM RMA#'])}
        OR [exfm rma#] IN {tuple(new_receive['ExFM RMA#'])})
        AND status IN ('0] CLOSED','4B] Declined Repair','6] QC','7] SHIPPED')
        ORDER BY status
    '''
completed = pd.read_sql(q,conn)
# completed.to_excel(f'inspection/completed_{today}.xlsx',index=False)
completed
# Out:
#                        Customer Name      MODEL         SN location  \
# 0         FUJIFILM Vietnam Co., Ltd.    EG-720R  JG402K330    Hanoi
# 1         FUJIFILM Vietnam Co., Ltd.    EP-6000  1V696K004    Hanoi
# 2  Hanoi Medical University Hospital   EG-600WR  KG391K796    Hanoi
# 3             Hoan My Sai Gon Clinic  EC-250WL5  1C309K073      HCM
# 4                   Dam Doi Hospital  EG-250WR5  SG202A469      HCM
# 5         FUJIFILM Vietnam Co., Ltd.  EC-590WL4  1C666K485      HCM
# 6         FUJIFILM Vietnam Co., Ltd.  EC-720R/I  1C741K089    Hanoi
#
#   repair_size               Issue      STATUS    End Date     Shipped  \
# 0       Minor                 CLN   0] CLOSED  2024-01-22  2024-01-22
# 1       Other                   O   0] CLOSED  2024-01-22  2024-01-22
# 2      Return                 BSA       6] QC        None        None
# 3       Minor                None       6] QC  2024-01-23        None
# 4      Return  LGB, FSA, FSB, PCB  7] SHIPPED        None  2024-01-24
# 5      Return            OSA, VCA  7] SHIPPED        None  2024-01-23
# 6      Return            CHA, FSB  7] SHIPPED        None  2024-01-23
#
#         ExFM RMA#
# 0  FMSV2024010033
# 1  FMSV2024010035
# 2  FMSV2024010028
# 3  FMSV2024010036
# 4  FMSV2023090073
# 5  FMSV2024010004
# 6  FMSV2024010034

# %% [markdown]
# ### Analys

# %%
conn = connect('history.db')

# %% [markdown]
# ###### 1. Receive

# %%
q = '''
        SELECT [exfm rma#] ,[customer name],[model],[sn],location
        FROM new_ml
        WHERE status = '1] RECEIVE'
    '''
pd.read_sql(q,conn)
# Out:
#         ExFM RMA#               Customer Name      MODEL         SN Location
# 0  FMSV2023120050         FTYO - Loaner Asset   EG-600WR  2G391K630    Hanoi
# 1  FMSV2024010034  FUJIFILM Vietnam Co., Ltd.  EC-720R/I  1C741K089    Hanoi
# 2  FMSV2024010027        Hue Central Hospital  EC-530WL3  KC643K009      HCM
# 3  FMSV2024010037  FUJIFILM Vietnam Co., Ltd.   EG-600WR  9G391K366    Hanoi
# 4  FMSV2024010036      Hoan My Sai Gon Clinic  EC-250WL5  1C309K073      HCM

# %% [markdown]
# ###### 2. Inspection

# %%
q = '''
        SELECT [exfm rma#] ,[customer name],[model],[sn],location,
        [status info],[due date],[internal note],[quote price (vnd)] AS Price
        FROM new_ml
        WHERE status = '2] INSPECTION'
        AND Price IS NOT NULL
    '''
pd.read_sql(q,conn)
# Out:
#          ExFM RMA#                 Customer Name         MODEL         SN  \
# 0   FMSV2023110009             Hoang Long Clinic     VP-4450HD  1V567K251
# 1   FMSV2023110025             Bach Mai Hospital      EG-600WR  8G391K370
# 2   FMSV2023110026             Bach Mai Hospital      EG-600WR  8G391K367
# 3   FMSV2023110027             Bach Mai Hospital      EC-600WI  6C692K198
# 4   FMSV2023110028             Bach Mai Hospital      EC-590WI  1C607K025
# 5   FMSV2023110045             Hoang Long Clinic      EG-600WR  1G391K374
# 6   FMSV2023110046             Hoang Long Clinic  EC-760ZP-V/M  1C730K109
# 7   FMSV2023110047             Hoang Long Clinic      EG-600WR  1G391K515
# 8   FMSV2023110048             Hoang Long Clinic  EC-760ZP-V/M  1C730K142
# 9   FMSV2023110050             Hoang Long Clinic  EC-760ZP-V/M  1C730K143
# 10  FMSV2023110052             Hoang Long Clinic      EC-600WI  1C692K644
# 11  FMSV2023110055             Hoang Long Clinic       EG-760Z  1G403K205
# 12  FMSV2023110059    FUJIFILM Vietnam Co., Ltd.      EC-600WL  1C692K147
# 13  FMSV2023110065             Hoang Long Clinic       EG-760Z  1G403K433
# 14  FMSV2023120009             Hoang Long Clinic      EG-600WR  1G391K988
# 15  FMSV2024010025  Tra Vinh Pediatrics Hospital     EG-250WR5  2G202K073
#
#    Location            Status Info Due Date  \
# 0     Hanoi  Awating Parts billing     None
# 1     Hanoi  Awating Parts billing     None
# 2     Hanoi  Awating Parts billing     None
# 3     Hanoi  Awating Parts billing     None
# 4     Hanoi  Awating Parts billing     None
# 5     Hanoi  Awating Parts billing     None
# 6     Hanoi  Awating Parts billing     None
# 7     Hanoi  Awating Parts billing     None
# 8     Hanoi  Awating Parts billing     None
# 9     Hanoi  Awating Parts billing     None
# 10    Hanoi  Awating Parts billing     None
# 11    Hanoi  Awating Parts billing     None
# 12      HCM  Awating Parts billing     None
# 13    Hanoi  Awating Parts billing     None
# 14    Hanoi  Awating Parts billing     None
# 15      HCM                   None     None
#
#                                   Internal Note      Price
# 0                                          None  250000000
# 1                                          None   84000000
# 2   Treated by Air dryer system 16/11/23 - fail  253000000
# 3                                           FOC        FOC
# 4                                          None   86000000
# 5                                          None  209000000
# 6                                          None  330000000
# 7                                          None   15000000
# 8                                          None  393000000
# 9                                          None  393000000
# 10                                         None   79000000
# 11                                         None   17000000
# 12                                   Scope leak   60000000
# 13                                         None  332000000
# 14                                         None   69000000
# 15                                BVDK Tra Vinh   32000000

# %% [markdown]
# ###### 3. Part Selection

# %%
# No Price
q = '''
        SELECT [exfm rma#] ,[customer name],[model],[sn],location,
        [status info],[information from cusomter],[due date],[internal note],[quote price (vnd)] AS Price
        FROM new_ml
        WHERE status = '3] PARTS SELECTION'
        AND PRICE IS NULL
    '''
pd.read_sql(q,conn)

# %% [markdown]
# ###### Activity this week

# %%
week_day = dt.now().weekday()

# %%
from datetime import datetime, timedelta

N_DAYS_AGO = 5

today = datetime.now()    
monday = today - timedelta(days=week_day)
print (monday)
# Out:
# 2024-01-22 10:03:10.682631

# %%
type(monday)
# Out:
# datetime.datetime

# %%
monday.strftime('%Y-%m-%d')
# Out:
# '2024-01-22'

# %%
aa

# %%
# monday = ''
monday = monday.strftime('%Y-%m-%d')
q = f'''
        SELECT * 
        
        FROM consolidated
        WHERE [UPDATE TIME] >'{monday}'
        ORDER BY [update time]
    '''
activity_this_week = pd.read_sql(q,conn)
activity_this_week.to_sql('thisweek',conn,if_exists = 'replace')
# Out:
# 67

# %%
# REceive
q = f'''
        SELECT [rma no.] ,[customer_name],[model],[serial_no],
        strftime('%Y-%m-%d',recieve_date) AS [Receive Date],
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location
        
        From ((((thisweek c
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name
        where recieve_date > '{monday}'
    '''
pd.read_sql(q,conn)
# Out:
#           RMA No.                               CUSTOMER_NAME           MODEL  \
# 0  FMSV2024010037                  FUJIFILM Vietnam Co., Ltd.        EG-600WR
# 1  FMSV2024010038  Vietnam – Cuba Donghoi Friendship Hospital         EG-760R
# 2  FMSV2024010039                  FUJIFILM Vietnam Co., Ltd.        EG-530WR
# 3  FMSV2024010040                  FUJIFILM Vietnam Co., Ltd.  EPX-2500(230V)
# 4  FMSV2024010041            Hai Phong International Hospital       EG-250WR5
# 5  FMSV2024010042            Hai Phong International Hospital       EG-250WR5
# 6  FMSV2024010043                  FUJIFILM Vietnam Co., Ltd.        EC-530WI
# 7  FMSV2024010044                   Tra Vinh General Hospital       EC-250WL5
#
#    SERIAL_NO Receive Date location
# 0  9G391K366   2024-01-22    Hanoi
# 1  KG402K677   2024-01-23    Hanoi
# 2  4G361K141   2024-01-23    Hanoi
# 3  5V564D396   2024-01-23    Hanoi
# 4  2G202K044   2024-01-23    Hanoi
# 5  2G202K043   2024-01-23    Hanoi
# 6  1C603K041   2024-01-23    Hanoi
# 7  3C309K056   2024-01-23      HCM

# %%
# Inspection fix location
q = f'''
        SELECT [rma no.] ,[customer_name],[model],[serial_no],
        strftime('%Y-%m-%d',recieve_date) AS [Receive Date],
        strftime('%Y-%m-%d',in_inspect_date) AS [Inspect Date],
        in_inspect_user_name as [Inspector],
        
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location
        From ((((thisweek c
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name
        where in_inspect_date > '{monday}'
    '''
pd.read_sql(q,conn)
# Out:
#           RMA No.               CUSTOMER_NAME      MODEL  SERIAL_NO  \
# 0  FMSV2024010027        Hue Central Hospital  EC-530WL3  KC643K009
# 1  FMSV2024010036      Hoan My Sai Gon Clinic  EC-250WL5  1C309K073
# 2  FMSV2024010034  FUJIFILM Vietnam Co., Ltd.  EC-720R/I  1C741K089
#
#   Receive Date Inspect Date         Inspector location
# 0   2024-01-19   2024-01-23       Nguyen Thai      HCM
# 1   2024-01-19   2024-01-22       Nguyen Thai      HCM
# 2   2024-01-19   2024-01-23  Nguyen Tuan Minh    Hanoi

# %%
# Sent Quote/Approval
q = f'''
        SELECT [rma no.] ,[customer_name],[model],[serial_no],
        strftime('%Y-%m-%d',in_inspect_date) AS [Inspect Date],
        strftime('%Y-%m-%d',[Part Select Date]) AS [Quote Date],
        
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location
        From ((((thisweek c
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name
        where [Part Select Date] > '{monday}'
    '''
pd.read_sql(q,conn)
# Out:
#            RMA No.                      CUSTOMER_NAME        MODEL  SERIAL_NO  \
# 0   FMSV2024010027               Hue Central Hospital    EC-530WL3  KC643K009
# 1   FMSV2024010036             Hoan My Sai Gon Clinic    EC-250WL5  1C309K073
# 2   FMSV2024010034         FUJIFILM Vietnam Co., Ltd.    EC-720R/I  1C741K089
# 3   FMSV2024010004         FUJIFILM Vietnam Co., Ltd.    EC-590WL4  1C666K485
# 4   FMSV2023120015         FUJIFILM Vietnam Co., Ltd.      XL-4450  1S094A418
# 5   FMSV2023120017                FTYO - Loaner Asset  EC-590ZW3/M  1C610D007
# 6   FMSV2023120029         FUJIFILM Vietnam Co., Ltd.    EC-530WI3  1C642K363
# 7   FMSV2023120020         FUJIFILM Vietnam Co., Ltd.    EG-580NW2  1G390K230
# 8   FMSV2023110059         FUJIFILM Vietnam Co., Ltd.     EC-600WL  1C692K147
# 9   FMSV2023120042                         HCAP asset     EC-600WL  1C692K065
# 10  FMSV2024010028  Hanoi Medical University Hospital     EG-600WR  KG391K796
#
#    Inspect Date  Quote Date location
# 0    2024-01-23  2024-01-23      HCM
# 1    2024-01-22  2024-01-22      HCM
# 2    2024-01-23  2024-01-23    Hanoi
# 3    2024-01-09  2024-01-23    Hanoi
# 4    2023-12-18  2024-01-24    Hanoi
# 5    2023-12-18  2024-01-24      HCM
# 6    2023-12-19  2024-01-24    Hanoi
# 7    2023-12-22  2024-01-24      HCM
# 8    2023-11-23  2024-01-24      HCM
# 9    2024-01-09  2024-01-24      HCM
# 10   2024-01-18  2024-01-22    Hanoi

# %%
# Get Confirmation
q = f'''
        SELECT [rma no.] ,[customer_name],[model],[serial_no],
        strftime('%Y-%m-%d',[Part Select Date]) AS [Quote Date],
        strftime('%Y-%m-%d',[AUTHORIZED_DATE]) AS [Confirm Date],
        [other id],
        
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location
        From ((((thisweek c
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name
        where [AUTHORIZED_DATE] > '{monday}'
    '''
pd.read_sql(q,conn)
# Out:
#           RMA No.                      CUSTOMER_NAME      MODEL  SERIAL_NO  \
# 0  FMSV2023110071  Hanoi Medical University Hospital   EG-600WR  KG391K801
# 1  FMSV2023110072  Hanoi Medical University Hospital   EG-600WR  KG391K797
# 2  FMSV2023120024  Hanoi Medical University Hospital   EG-600WR  KG391K800
# 3  FMSV2024010027               Hue Central Hospital  EC-530WL3  KC643K009
# 4  FMSV2024010036             Hoan My Sai Gon Clinic  EC-250WL5  1C309K073
# 5  FMSV2024010034         FUJIFILM Vietnam Co., Ltd.  EC-720R/I  1C741K089
# 6  FMSV2024010004         FUJIFILM Vietnam Co., Ltd.  EC-590WL4  1C666K485
# 7  FMSV2023090073                   Dam Doi Hospital  EG-250WR5  SG202A469
# 8  FMSV2024010028  Hanoi Medical University Hospital   EG-600WR  KG391K796
#
#    Quote Date Confirm Date          Other ID location
# 0  2023-12-13   2024-01-22  WTY-FFVN-2311056    Hanoi
# 1  2023-12-13   2024-01-22  WTY-FFVN-2311057    Hanoi
# 2  2023-12-18   2024-01-22  WTY-FFVN-2312062    Hanoi
# 3  2024-01-23   2024-01-23              None      HCM
# 4  2024-01-22   2024-01-22              None      HCM
# 5  2024-01-23   2024-01-23              None    Hanoi
# 6  2024-01-23   2024-01-23              None    Hanoi
# 7  2023-10-07   2024-01-23              None      HCM
# 8  2024-01-22   2024-01-24  WTY-FFVN-2401005    Hanoi

# %%
# Repair
q = f'''
        SELECT DISTINCT c.[rma no.] ,[customer_name],[model],[serial_no],
        strftime('%Y-%m-%d',[AUTHORIZED_DATE]) AS [Confirm Date],
        strftime('%Y-%m-%d',r.[start time]) AS [Start Date],
        strftime('%Y-%m-%d',c.[qc]) AS [End Date],
        CASE
            WHEN r.[end user] IS NOT NULL THEN r.[end user]
            ELSE r.[start user] END AS Repairer,
        
        [other id],
        
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location
        From (((((thisweek c
        LEFT JOIN repair_code r ON c.[rma no.] = r.[rma no.])
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name
        
        where r.[start time] > '{monday}'
    '''
pd.read_sql(q,conn)
# Out:
#           RMA No.                                    CUSTOMER_NAME      MODEL  \
# 0  FMSV2024010036                           Hoan My Sai Gon Clinic  EC-250WL5
# 1  FMSV2023090237  Hue University Of Medicine And Pharmacy - Ginec   EG-530CT
# 2  FMSV2024010027                             Hue Central Hospital  EC-530WL3
#
#    SERIAL_NO Confirm Date  Start Date    End Date        Repairer Other ID  \
# 0  1C309K073   2024-01-22  2024-01-22  2024-01-23     Nguyen Thai     None
# 1  4G375A101   2023-12-11  2024-01-22        None  Le Quang Thong    PO116
# 2  KC643K009   2024-01-23  2024-01-23        None     Nguyen Thai     None
#
#   location
# 0      HCM
# 1      HCM
# 2      HCM

# %%
# Ship out
q = f'''
        SELECT DISTINCT c.[rma no.] ,[customer_name],[model],[serial_no],
        strftime('%Y-%m-%d',[recieve_date]) AS [Receive Date],
        strftime('%Y-%m-%d',[in_inspect_date]) AS [Inspect Date],
        strftime('%Y-%m-%d',c.[qc]) AS [End Date],
        strftime('%Y-%m-%d',c.[shipped]) AS [Ship Date],
        CASE
            WHEN r.[end user] IS NOT NULL THEN r.[end user]
            ELSE r.[start user] END AS Repairer,
        
        [other id],
        
        CASE
            WHEN c.ship_user_name IS NOT NULL THEN ship.location
            WHEN c.[repair user name] IS NOT NULL THEN repair.location
            WHEN c.in_inspect_user_name IS NOT NULL THEN inspect.location
            ELSE (receive.location) END AS location,
        repair_status
        From (((((thisweek c
        LEFT JOIN repair_code r ON c.[rma no.] = r.[rma no.])
        LEFT JOIN engineers e ON c.[repair user name] = e.exfm_name)
        LEFT JOIN engineers receive ON c.RECIEVE_USER_NAME = receive.exfm_name)
        LEFT JOIN engineers inspect ON c.in_inspect_user_name = inspect.exfm_name)
        LEFT JOIN engineers repair ON c.[repair user name] = repair.exfm_name)
        LEFT JOIN engineers ship ON c.ship_user_name = ship.exfm_name
        
        WHERE c.shipped > '{monday}'
        ORDER BY [ship date]
    '''
pd.read_sql(q,conn)
# Out:
#            RMA No.                                CUSTOMER_NAME         MODEL  \
# 0   FMSV2023110073            Hanoi Medical University Hospital      EG-600WR
# 1   FMSV2023120054                 245 Clinic - Dr.Cuong Clinic     EC-250WL5
# 2   FMSV2023120011            Hanoi Medical University Hospital      EG-600WR
# 3   FMSV2023120014            Hanoi Medical University Hospital       XL-4450
# 4   FMSV2023120025                  Hung Cuong General Hospital      EG-530WR
# 5   FMSV2023120026                   FUJIFILM Vietnam Co., Ltd.       EG-760R
# 6   FMSV2023120031          Nghe An Friendship General Hospital     EC-530WL3
# 7   FMSV2023120035                   FUJIFILM Vietnam Co., Ltd.      EC-530WI
# 8   FMSV2023120044                   FUJIFILM Vietnam Co., Ltd.       VP-7000
# 9   FMSV2023120045                   FUJIFILM Vietnam Co., Ltd.       BL-7000
# 10  FMSV2023120046                   FUJIFILM Vietnam Co., Ltd.       EG-760R
# 11  FMSV2023120047                   FUJIFILM Vietnam Co., Ltd.  EC-760ZP-V/M
# 12  FMSV2023120052                   FUJIFILM Vietnam Co., Ltd.      EG-530WR
# 13  FMSV2023120053                           Thai Binh Hospital     EC-530WL3
# 14  FMSV2024010016                            Bach Mai Hospital      EG-600WR
# 15  FMSV2024010033                   FUJIFILM Vietnam Co., Ltd.       EG-720R
# 16  FMSV2024010035                   FUJIFILM Vietnam Co., Ltd.       EP-6000
# 17  FMSV2023120006                           Thai Binh Hospital      EG-530WR
# 18  FMSV2023110042                            Hoang Long Clinic  EC-760ZP-V/M
# 19  FMSV2023110044                            Hoang Long Clinic   EC-760R-V/I
# 20  FMSV2023110043                            Hoang Long Clinic  EC-760ZP-V/M
# 21  FMSV2023110040                            Hoang Long Clinic       EG-760Z
# 22  FMSV2023110037              Hai Duong Tuberculosis Hospital       EB-530T
# 23  FMSV2023110041                            Hoang Long Clinic  EC-760ZP-V/M
# 24  FMSV2023060047                            Hoang Long Clinic       EG-760Z
# 25  FMSV2023090289            Hanoi Medical University Hospital       XL-4450
# 26  FMSV2023090069  Phu Tho General Hospital - Pediatric Center      EG-530FP
# 27  FMSV2023090290            Hanoi Medical University Hospital       XL-4450
# 28  FMSV2023100030       Viet Nhat Clinic 3 - Dr.Giang'S Clinic     EG-530UR2
# 29  FMSV2023090252            Hanoi Medical University Hospital       XL-4450
# 30  FMSV2023090163            Hanoi Medical University Hospital       XL-4450
# 31  FMSV2023090074  Phu Tho General Hospital - Pediatric Center      EG-530FP
# 32  FMSV2023090246            Hanoi Medical University Hospital       XL-4450
# 33  FMSV2023110024                            Bach Mai Hospital     EC-590WL4
# 34  FMSV2023070077                   FUJIFILM Vietnam Co., Ltd.      EG-600WR
# 35  FMSV2023090080            Hanoi Medical University Hospital       XL-4450
# 36  FMSV2024010034                   FUJIFILM Vietnam Co., Ltd.     EC-720R/I
# 37  FMSV2024010004                   FUJIFILM Vietnam Co., Ltd.     EC-590WL4
# 38  FMSV2023090073                             Dam Doi Hospital     EG-250WR5
#
#     SERIAL_NO Receive Date Inspect Date    End Date   Ship Date  \
# 0   KG391K792   2023-11-30   2023-12-12        None  2024-01-22
# 1   3C309K057   2023-12-29   2024-01-09  2024-01-22  2024-01-22
# 2   KG391K781   2023-12-08   2023-12-08  2023-12-11  2024-01-22
# 3   2S094K444   2023-12-08   2023-12-20  2024-01-12  2024-01-22
# 4   JG361K231   2023-12-15   2023-12-22  2024-01-02  2024-01-22
# 5   2G402K099   2023-12-15   2023-12-15  2024-01-02  2024-01-22
# 6   5C643K347   2023-12-20   2023-12-28  2024-01-05  2024-01-22
# 7   1C603K041   2023-12-21   2023-12-22  2024-01-02  2024-01-22
# 8   6V644K427   2023-12-27   2023-12-29  2024-01-02  2024-01-22
# 9   7S101K272   2023-12-27   2023-12-29  2024-01-02  2024-01-22
# 10  JG402K336   2023-12-27   2023-12-29  2024-01-02  2024-01-22
# 11  2C730K026   2023-12-27   2023-12-29  2024-01-02  2024-01-22
# 12  4G361K141   2023-12-28   2024-01-03  2024-01-12  2024-01-22
# 13  KC643K248   2023-12-28   2024-01-02  2024-01-05  2024-01-22
# 14  KG391K506   2024-01-09   2024-01-11  2024-01-12  2024-01-22
# 15  JG402K330   2024-01-19   2024-01-19  2024-01-22  2024-01-22
# 16  1V696K004   2024-01-19   2024-01-19  2024-01-22  2024-01-22
# 17  LG361K357   2023-12-05   2023-12-07  2024-01-02  2024-01-22
# 18  1C730K144   2023-11-20   2023-11-27  2023-12-01  2024-01-22
# 19  1C728K175   2023-11-20   2023-11-23  2023-11-27  2024-01-22
# 20  1C730K104   2023-11-20   2023-11-27  2023-12-01  2024-01-22
# 21  1G403K227   2023-11-20   2023-11-23  2023-11-24  2024-01-22
# 22  1B084K198   2023-11-17   2023-11-17  2023-11-27  2024-01-22
# 23  1C730K119   2023-11-20   2023-11-24  2023-11-27  2024-01-22
# 24  1G403K110   2023-06-19   2023-06-20  2023-12-13  2024-01-22
# 25  3S094K015   2023-09-28   2023-09-29  2023-12-22  2024-01-22
# 26  4G374K157   2023-09-28   2023-09-28  2023-12-13  2024-01-22
# 27  3S094K526   2023-09-28   2023-09-29  2023-12-11  2024-01-22
# 28  RU039A048   2023-10-19   2023-10-31  2023-11-09  2024-01-22
# 29  2S094K540   2023-09-28   2023-09-29  2023-12-22  2024-01-22
# 30  3S094K544   2023-09-28   2023-09-29  2023-12-22  2024-01-22
# 31  4G374K154   2023-09-28   2023-09-29  2023-12-22  2024-01-22
# 32  3S094K980   2023-09-28   2023-09-29  2023-12-11  2024-01-22
# 33  1C666K567   2023-11-15   2023-11-17  2023-11-27  2024-01-22
# 34  1G391K315   2023-07-31   2023-08-02  2024-01-12  2024-01-22
# 35  2S094K543   2023-09-28   2023-09-29  2023-12-11  2024-01-22
# 36  1C741K089   2024-01-19   2024-01-23        None  2024-01-23
# 37  1C666K485   2024-01-03   2024-01-09        None  2024-01-23
# 38  SG202A469   2023-09-28   2023-09-29        None  2024-01-24
#
#                      Repairer          Other ID location REPAIR_STATUS
# 0                        None  WTY-FFVN-2311058    Hanoi     Completed
# 1                       hoang              None      HCM     Completed
# 2   Nguyen Khac Thang (Hanoi)              None    Hanoi     Completed
# 3            Nguyen Tuan Minh              None    Hanoi     Completed
# 4   Nguyen Khac Thang (Hanoi)              None    Hanoi     Completed
# 5   Nguyen Khac Thang (Hanoi)              None    Hanoi     Completed
# 6                 Le Van Hoan              None    Hanoi     Completed
# 7                 Le Van Hoan              None    Hanoi     Completed
# 8            Nguyen Tuan Minh              None    Hanoi     Completed
# 9            Nguyen Tuan Minh              None    Hanoi     Completed
# 10           Nguyen Tuan Minh              None    Hanoi     Completed
# 11           Nguyen Tuan Minh              None    Hanoi     Completed
# 12           Nguyen Tuan Minh              None    Hanoi     Completed
# 13           Nguyen Tuan Minh              None    Hanoi     Completed
# 14           Nguyen Tuan Minh              None    Hanoi     Completed
# 15           Nguyen Tuan Minh              None    Hanoi     Completed
# 16           Nguyen Tuan Minh              None    Hanoi     Completed
# 17                Le Van Hoan              None    Hanoi     Completed
# 18                Le Van Hoan              None    Hanoi     Completed
# 19                Le Van Hoan              None    Hanoi     Completed
# 20                Le Van Hoan              None    Hanoi     Completed
# 21  Nguyen Khac Thang (Hanoi)              None    Hanoi     Completed
# 22                Le Van Hoan              None    Hanoi     Completed
# 23                Le Van Hoan              None    Hanoi     Completed
# 24                Le Van Hoan              None    Hanoi     Completed
# 25           Nguyen Tuan Minh              None    Hanoi     Completed
# 26  Nguyen Khac Thang (Hanoi)              None    Hanoi     Completed
# 27                Le Van Hoan              None    Hanoi     Completed
# 28  Nguyen Khac Thang (Hanoi)              None    Hanoi     Completed
# 29           Nguyen Tuan Minh              None    Hanoi     Completed
# 30           Nguyen Tuan Minh              None    Hanoi     Completed
# 31           Nguyen Tuan Minh              None    Hanoi     Completed
# 32                Le Van Hoan              None    Hanoi     Completed
# 33                Le Van Hoan              None    Hanoi     Completed
# 34           Nguyen Tuan Minh              None    Hanoi     Completed
# 35                Le Van Hoan              None    Hanoi     Completed
# 36                       None              None    Hanoi       Shipped
# 37                       None              None    Hanoi       Shipped
# 38                       None              None      HCM       Shipped
