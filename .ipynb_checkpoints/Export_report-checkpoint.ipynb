# %%
import xlwings as xw
import sources.parts_list_bk0426 as pl
import pandas as pd
import os
from datetime import datetime as dt
import sources.logins as lg
import pathlib
import qrcode
from time import sleep
import xlwings as xw
from IPython.display import Image
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
from cryptography.fernet import Fernet
# Generate a key
# key = Fernet.generate_key()
key = str('HfOfd2sE7RO8TQ21qckawMG82uTchV_kQC4o7EZYTPE=').encode()


def pw_encode(message,key):
    fernet = Fernet(key)
#     fernet = key
    message = message.encode()
    b_msg = fernet.encrypt(message)
    return b_msg.decode()


def pw_decode(encrypted_message,key):
    
    fernet = Fernet(key)
#     fernet = key
    encrypted_message = encrypted_message.encode()
    b_encrypt_msg = fernet.decrypt(encrypted_message)
    return b_encrypt_msg.decode()

# %%
#Date endcode
file = 'license\\log.txt'

expire_date = '2022-07-28'
date_code = pw_encode(expire_date,key)
date_code
files = open(file,'w')
files.write(date_code)
files.close()

# %%
date_code
# Out:
# 'gAAAAABkXfNoW5Y9gBysLfDkXxrcrwkiQ8KBP39W_3NcXx-7X22oArF8XO52dvRTmnb-ndOHojkdfPQlk8LMbQozfZ4f5WEf9Q=='

# %%
# main
# file = 'license\\log.txt'
while True:
    if os.path.exists(file): # read data key
        logs = open(file,'r')
        data = logs.read()
        logs.close()
        key_date = data.split('\n')[0]
        try:
            # check Date code
            dt_date_code = dt.strptime(pw_decode(key_date,key),'%Y-%m-%d')
        except:
            print('Wrong key. Please update new key.')
            break
        if dt.now() <= dt_date_code:
            
            print(f"License key will expire on {dt_date_code.strftime('%Y-%m-%d')}")
            break
                  # continue hể
        else:
            print('License key was expired. Please update new key.')
            str_key = input('Date Key: ')
            files = open(file,'w')
            files.write(str_key)
            files.close()
    else:
        str_key = input('Date Key: ')
        files = open(file,'w')
        files.write(str_key)
        files.close()
# Out:
# License key will expire on 2023-07-28

# %%
from sqlite3 import connect
conn = connect('quotation.db')

# %%
#Select RMA or SN:
sn = str(input('Search by Serial or RMA: '))
if sn.upper().strip() == 'UPDATE':
    pass 
else:
    q=f'''
            SELECT c.[rma no.] AS rma,c.customer_name,c.serial_no,c.model,c.approval,c.repair_status,c.in_inspect_user_name
            FROM consolidated c
            WHERE upper(c.serial_no) like '%{sn.upper()}%' or  upper(c.[rma no.]) like '%{sn.upper()}%'
            ORDER BY rma DESC
        '''
    results = pd.read_sql(q,conn)
if len(results)>0:
    display(pd.read_sql(q,conn))
# elif sn.upper().strip() == 'QUIT' or sn.upper().strip() == 'EXIT' or sn.upper().strip() == 'DONE':
#     break
else:
    print(f'\nCan not search with key "{sn}"')
#     continue

#Select Index
while True:
    try:
        ind = int(input('\nSelect RMA by index (Default 0): ') or 0)
        break
    except:
        print('Only Accept number') 
for i in range(results.shape[1]):
    print("{0:40} {1}".format(results.columns[i],results.iloc[ind][i]))


# Confirm RMA
confirm = str(input(f' Confirm Select RMA"{results.iloc[ind][0]}"? (y/N)') or 'N')
if confirm.upper() =='Y':
    rma = results.iloc[ind][0]
else:
    rma=''
#     continue
# Out:
# Search by Serial or RMA: 361
#                rma                                     CUSTOMER_NAME  \
# 0   FMSV2023040042                                       ETC Company
# 1   FMSV2023040039  Thien Duc International General Hospital- Ha Noi
# 2   FMSV2023040037                        FUJIFILM Vietnam Co., Ltd.
# 3   FMSV2023040032                     Northwestern Nghe An hospital
# 4   FMSV2023040020                        Dong Thap General Hospital
# 5   FMSV2023040018                   Thai Binh city general hospital
# 6   FMSV2023040014                        FUJIFILM Vietnam Co., Ltd.
# 7   FMSV2023030068                      245 Clinic - Dr.Cuong Clinic
# 8   FMSV2023030059               Nghe An Friendship General Hospital
# 9   FMSV2023030048                        FUJIFILM Vietnam Co., Ltd.
# 10  FMSV2023030043                             Tay Nguyen University
# 11  FMSV2023030041   Hue University of Medicine and Pharmacy - Ginec
# 12  FMSV2023020039               Nghe An Friendship General Hospital
# 13  FMSV2023020011                       Than Uyen District Hospital
# 14  FMSV2023010027               Nghe An Friendship General Hospital
# 15  FMSV2023010018                        FUJIFILM Vietnam Co., Ltd.
#
#     SERIAL_NO     MODEL  Approval  REPAIR_STATUS       IN_INSPECT_USER_NAME
# 0   4G361K017  EG-530WR  Approval  Authorization             Le Quang Thong
# 1   2G361K188  EG-530WR      None     Inspection  Nguyen Khac Thang (Hanoi)
# 2   4G361K141  EG-530WR  Approval             QC           Nguyen Tuan Minh
# 3   5G361K446  EG-530WR      None     Inspection           Nguyen Tuan Minh
# 4   7G361K162  EG-530WR      None     Inspection             Le Quang Thong
# 5   LG361K344  EG-530WR  Approval  Authorization           Nguyen Tuan Minh
# 6   5G361K065  EG-530WR  Approval         Repair             Le Quang Thong
# 7   9G361K614  EG-530WR      None     Inspection                Nguyen Thai
# 8   2G361K799  EG-530WR  Approval         Repair  Nguyen Khac Thang (Hanoi)
# 9   5G361K119  EG-530WR      None     Inspection             Le Quang Thong
# 10  1G361K704  EG-530WR      None     Inspection             Le Quang Thong
# 11  4G361A481  EG-530WR      None     Inspection             Le Quang Thong
# 12  2G361K831  EG-530WR      None     Inspection                Le Van Hoan
# 13  5G361K443  EG-530WR      None     Inspection  Nguyen Khac Thang (Hanoi)
# 14  8G361K199  EG-530WR      None     Inspection                Le Van Hoan
# 15  4G361K368  EG-530WR      None     Inspection  Nguyen Khac Thang (Hanoi)
# Select RMA by index (Default 0): 4
# rma                                      FMSV2023040020
# CUSTOMER_NAME                            Dong Thap General Hospital
# SERIAL_NO                                7G361K162
# MODEL                                    EG-530WR
# Approval                                 None
# REPAIR_STATUS                            Inspection
# IN_INSPECT_USER_NAME                     Le Quang Thong
#  Confirm Select RMA"FMSV2023040020"? (y/N)y

# %%
report_num = int(rma.split('FMSV')[1])

# %%
report_num
# Out:
# 2023040020

# %%
# create gdkt and add infomation to summary

# read lastrow
# d = pl.summary_report()
# summary_file = d.read_summary_data('2023_FFVN Service Endo_Inspection, WTY & TR.xlsx')
# gdkt = d.read_summary_data('2023_FFVN Service Endo_Inspection, WTY & TR.xlsx','gdkt')
# gdkt_lr = summary_file['gdkt'][0]

# report tu dong original

report_num = report_num = int(rma.split('FMSV')[1])

folder_name = 'reports_' + dt.now().strftime('%y%m%d')
try:
    os.mkdir(folder_name)
    print(f'folder {folder_name} was created.')
except:
    print(f'Folder {folder_name} exists')

i_report = 0
q_gdkt = {}
report_id = {}
d = pl.summary_report()



# for rma in list_rma['rma']:
    
i_report +=1
# report_num += 1
#add zero to report number
# if len(str(report_num))==1: report_num_str = f'00{report_num}'
# if len(str(report_num))==2: report_num_str = f'0{report_num}'
# if len(str(report_num))==3: report_num_str = f'{report_num}'

report_num_str = str(report_num)
# not number
#     report_num_str = 'xxx'

info = []
part_list= []
c = pl.technical_report()
info,part_list = c.report_info(rma,conn)
model = info['MODEL'][0]
sn = info['SERIAL_NO'][0]
#     c = pl.technical_report(info,report_num,part_list)
c.create_qr_image(info)
tp = c.report(conn,info,part_list,report_num_str)
c.save_and_close(tp,report_num_str,model,sn,folder_name)
q_gdkt.update({rma:(info,part_list)})    

# record to file summary

# gdkt.range('A' + str(gdkt_lr + i_report)).value = report_num_str
# wn = str(info['web_name'][0]).replace('Bệnh viện','BV')
# wn = wn.replace('Phòng Khám','PK')
# gdkt.range('B' + str(gdkt_lr + i_report)).value = wn

# gdkt.range('C' + str(gdkt_lr + i_report)).value = model.replace(' V2','')
# gdkt.range('D' + str(gdkt_lr + i_report)).value = sn
# gdkt.range('E' + str(gdkt_lr + i_report)).value = d.issues(conn,rma)
# sum_info = d.summary_info(conn,rma)
# gdkt.range('F' + str(gdkt_lr + i_report)).value = sum_info['first_name'][0]
# gdkt.range('M' + str(gdkt_lr + i_report)).value = rma#sum_info['first_name'][0]

# # take number to add SQL Master List
# report_id.update({sn:f"GDKT-{dt.now().strftime('%y%m')}{report_num_str}"})
# try:
#     gdkt.range('H' + str(gdkt_lr + i_report)).value =dt.strptime(sum_info['receive'][0],'%d/%m/%Y')
#     gdkt.range('I' + str(gdkt_lr + i_report)).value =dt.strptime(sum_info['inspect_date'][0],'%d/%m/%Y')
#     gdkt.range('G' + str(gdkt_lr + i_report)).value =dt.strptime(sum_info['date_installed'][0],'%d/%m/%Y')


#     q_gdkt.update({rma:(info,part_list)})
# except Exception as e:
#     print(e)
    
print('Done!!!')
# Out:
# Folder reports_230512 exists
# Exported FFVN-Endo-GDKT-23052023040020-EG530WR,7G361K162.xlsx
# Done!!!

# %%
c.report(conn,info,part_list,report_num_str)
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-53-78903f0c711a> in <module>
# ----> 1 c.report(conn,info,part_list,report_num_str)
#
# D:\Python\2023\sources\parts_list_bk0426.py in report(self, conn, info, part_list, report_num, folder)
#     774
#     775                 # add signatures
# --> 776                 self.signatures(tp)
#     777                 # code
#     778                 rma=info['RMA No.'][0]
#
# D:\Python\2023\sources\parts_list_bk0426.py in signatures(self, tp, signatures_folder)
#     686                         tp.pictures.add(os.path.join(path,signatures_folder,'Thang.png'),name = 'Thang',top = tp.range('G44').offset(1,0).top+7,left = tp.range('G44').offset(1,0).left-20)
#     687                 if tp.range('F50').value == 'Nguyễn Thái Nguyên':
# --> 688                         tp.pictures.add(os.path.join(path,signatures_folder,'Nguyen.png'),name = 'Nguyen',top = tp.range('G44').offset(1,0).top+7,left = tp.range('G44').offset(1,0).left-20)
#     689                 if tp.range('I50').value == 'Nguyễn Khắc Thắng':
#     690                         tp.pictures.add(os.path.join(path,signatures_folder,'Thang.png'),name = 'Thang',top = tp.range('G44').offset(1,0).top+7,left = tp.range('J44').offset(1,0).left-20)
#
# ~\Anaconda3\lib\site-packages\xlwings\main.py in add(self, image, link_to_file, save_with_document, left, top, width, height, name, update, scale, format, anchor, export_options)
#    4320                 width=im_width,
#    4321                 height=im_height,
# -> 4322                 anchor=anchor,
#    4323             )
#    4324         )
#
# ~\Anaconda3\lib\site-packages\xlwings\_xlwindows.py in add(self, filename, link_to_file, save_with_document, left, top, width, height, anchor)
#    2178                 Top=top,
#    2179                 Width=width,
# -> 2180                 Height=height,
#    2181             ).DrawingObject
#    2182         )
#
# ~\Anaconda3\lib\site-packages\xlwings\_xlwindows.py in __call__(self, *args, **kwargs)
#     103         while True:
#     104             try:
# --> 105                 v = self.__method(*args, **kwargs)
#     106                 if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     107                     return COMRetryObjectWrapper(v)
#
# ~\AppData\Local\Temp\gen_py\3.7\00020813-0000-0000-C000-000000000046x0x1x9.py in AddPicture(self, Filename, LinkToFile, SaveWithDocument, Left, Top, Width, Height)
#   36339 		ret = self._oleobj_.InvokeTypes(1723, LCID, 1, (9, 0), ((8, 1), (3, 1), (3, 1), (4, 1), (4, 1), (4, 1), (4, 1)),Filename
#   36340                         , LinkToFile, SaveWithDocument, Left, Top, Width
# > 36341 			, Height)
#   36342                 if ret is not None:
#   36343                         ret = Dispatch(ret, 'AddPicture', '{00024439-0000-0000-C000-000000000046}')
#
# com_error: (-2147352567, 'Exception occurred.', (0, None, "The specified file wasn't found.", None, 0, -2146827284), None)
