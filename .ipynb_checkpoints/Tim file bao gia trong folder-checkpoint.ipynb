# %%
import os
import pathlib
import xlwings as xw
path = 'F:\Technical Report'

# %%
# collect all folder to parents_list
parents = os.listdir(path)
parents_list = []
for parent in parents:
    try:
        os.listdir(os.path.join(path,parent))
        parents_list.append(parent)
    except:
        continue

# %%
app = xw.App(add_book=False)
app.display_alerts = False
# wb = app.books.api.Open(fullpath, UpdateLinks=False)

# %%
# find and open bao gia
threshold = 'FMSV2021'
rma_error = []
price_list = {}
for customer in parents_list:
# customer = parents_list[14]
    childs = os.listdir(os.path.join(path,customer))

    print(customer)
    for rma in childs:
        if 'FMSV' in rma and rma > threshold:
            try:
                files = os.listdir(os.path.join(path,customer,rma))
                for file in files:
                    # Select Bao gia
                    if 'Baogia_' in file and '.xls' in file and '~' not in file:
    #                     print(rma,file)
                        try:
                            wb = xw.Book(os.path.join(path,customer,rma,file),update_links = False)
            #                 wb = app.books.api.Open(os.path.join(path,customer,rma,file), UpdateLinks=False)
                            lr_row = 1
                            for sheet in wb.sheets:
                                if sheet.name in ('Quotation',):
                                    sh = sheet


                            lr_row = sh.range('F1000').end('up').row
                            try:
                                price = int(sh.range(f'F20').value)
                            except:
                                price = int(sh.range(f'F19').value)
                            print(rma,f'VND {price}')
                            price_list.update({rma:price})
                        except Exception as e:
                            print(rma,e)
                            rma_error.append(rma)
                        wb.close()
            except Exception as e:
                print(e)
                print(f'{customer} dont have {rma}')
                rma_error.append(rma)
                    
print('Done')
# Out:
# 0. EndoCare
# 0000000
# 103 Military Hospital
# FMSV2021060021 VND 40500000
# FMSV2022090037 (-2146827864, 'OLE error 0x800a01a8', None, None)
# 115 People Hospital
# FMSV2021030073 VND 5000000
# FMSV2021030073 VND 4000000
# FMSV2021030095 VND 100000000
# FMSV2022010013 VND 100000000
# FMSV2022040057 VND 75000000
# FMSV2022040058 VND 354500000
# FMSV2022040059 VND 34500000
# FMSV2022040060 VND 225500000
# FMSV2022060024 VND 120000000
# FMSV2022060086 VND 354500000
# FMSV2022100078 VND 199000000
# FMSV2022100079 VND 24000000
# 19.8 Hospital
# 199 Hospital
# FMSV2022010033 VND 75000000
# FMSV2022010033 VND 50000000
# 245 Clinic-Dr.Cuong Clinic
# FMSV2022020003 VND 33000000
# 333 Regional General Hospital
# FMSV2022100070 VND 28000000
# 354 Military Hospital
# FMSV2021110045 VND 47500000
# FMSV2021110046 VND 184500000
# FMSV2021110047 VND 184000000
# FMSV2021110048 VND 161500000
# FMSV2022020020 VND 175500000
# FMSV2022020021 VND 181000000
# 71 National Hospital
# FMSV2022030018 VND 112500000
# 87 Military Hospital
# Bac Giang Hospital
# FMSV2023040092 VND 106920000
# FMSV2023050053 VND 257000000
# Bac Lieu People Military Hospital
# Bac Thang Long Hospital
# FMSV2022050003 (-2146827864, 'OLE error 0x800a01a8', None, None)
# Bach Mai Hospital
# FMSV2021030042 VND 151000000
# FMSV2021030043 VND 178500000
# FMSV2021030047 VND 11500000
# FMSV2021030050 VND 19500000
# FMSV2021060010 VND 36000000
# FMSV2021060033 VND 13000000
# FMSV2021060034 VND 76500000
# FMSV2021090013 VND 20500000
# FMSV2021090041 int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# FMSV2021100045 int() argument must be a string, a bytes-like object or a real number, not 'NoneType'
# FMSV
# Phu Tho General Hospital - Pediatric Center
# FMSV2023040017 VND 173000000
# FMSV2023050033 VND 162000000
# Phu Tho Town Hospital
# Phu Xuyen district General hospital
# Phuoc Long General Hospital
# Phuong Dong General Hospital
# Phuong Nam Clinic
# Post and Telecommunications Hospital
# FMSV2021100024 VND 29000000
# PROMED VIET NAM
# Quang Duc Clinic
# Quang Ninh Obstetrics And Pediatrics Hospital
# FMSV2021050029 VND 174000000
# Quang Tri General Hospital
# Quang Uyen General Hospital
# Quang Yen General Hospital
# FMSV2022040061 VND 62000000
# quotation
# Quotation & Technical report 26-Apr-2018
# Quynh Luu general hospital- Nghe An province
# Sin Ho District Hospital
# Soc Son Hospital
# Son Tay General Hospital
# Song An Clinic
# Song Thuong Hospital
# Tam Anh General Hospital
# FMSV2022110057 VND 61000000
# Tam Tri Da Nang Hospital
# Tam Tri Dong Thap
# Tam Tri Saigon General Hospital
# FMSV2021040093 VND 74000000
# FMSV2022040055 VND 159000000
# Tan Ky Hospital - Nghe An Province
# FMSV2022080023 VND 46000000
# Tan Lac District Medical Center
# Tan Son Medical Center
# Tanh Linh General Hospital
# FMSV2021100031 VND 29000000
# Tay Nguyen Regional General Hospital
# FMSV2021010027 (-2146827864, 'OLE error 0x800a01a8', None, None)
# FMSV2021010027 VND 56000000
# FMSV2021120058 (-2146827864, 'OLE error 0x800a01a8', None, None)
# Tay Nguyen University

# %%
price_list
# Out:
# {}

# %%
for column in range(1,15):
    if 'Amount' in sh.cells(5,column).value:
        print(sh.cells(5,column).value)
        print(column)
        break
# Out:
# Total/
# Amount
# 8

# %%
sh.cells.last_cell.row
# Out:
# 1048576

# %%
# tr_lr = gdkt.range('A' + str(gdkt.cells.last_cell.row)).end('up').row # tr
sh.range('A'+str())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 sh.cells(sh.rows.Count, column).End(xlUp).row
#
# AttributeError: 'Sheet' object has no attribute 'rows'

# %%
lr_row = sh.cells(1000,column).end('up').row
int(round(sh.cells(lr_row,column).value))
# Out:
# 1176

# %%
'FMSV2020010001' > 'FMSV2020'
# Out:
# True

# %%
wb.close()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 wb.close()
#
# File ~\anaconda3\lib\site-packages\xlwings\main.py:1114, in Book.close(self)
#    1108 def close(self):
#    1109     """
#    1110     Closes the book without saving it.
#    1111
#    1112     .. versionadded:: 0.1.1
#    1113     """
# -> 1114     self.impl.close()
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:800, in Book.close(self)
#     799 def close(self):
# --> 800     self.xl.Close(SaveChanges=False)
#
# File ~\anaconda3\lib\site-packages\xlwings\_xlwindows.py:109, in COMRetryMethodWrapper.__call__(self, *args, **kwargs)
#     107 while True:
#     108     try:
# --> 109         v = self.__method(*args, **kwargs)
#     110         if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#     111             return COMRetryObjectWrapper(v)
#
# File ~\anaconda3\lib\site-packages\win32com\gen_py\00020813-0000-0000-C000-000000000046x0x1x9.py:46617, in _Workbook.Close(self, SaveChanges, Filename, RouteWorkbook)
#   46616 def Close(self, SaveChanges=defaultNamedOptArg, Filename=defaultNamedOptArg, RouteWorkbook=defaultNamedOptArg):
# > 46617 	return self._oleobj_.InvokeTypes(277, LCID, 1, (24, 0), ((12, 17), (12, 17), (12, 17)),SaveChanges
#   46618 		, Filename, RouteWorkbook)
#
# com_error: (-2147417848, 'The object invoked has disconnected from its clients.', None, None)
