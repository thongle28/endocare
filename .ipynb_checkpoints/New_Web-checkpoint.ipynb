# %%
import pandas as pd
from sqlite3 import connect
from datetime import datetime as dt
from IPython.display import Image, display

# %%
conn = connect('history.db')

# %%
conn.close()

# %%
# RMA LIST FROM MASTER PENDING
rma_list = []
q = '''
        SELECT rma FROM new_ml
    '''
try:
    rl = pd.read_sql(q,conn)
#     display(rl)
    for rma in rl['rma']:
        rma_list.append(rma)
except Exception as e:
    
    print(e)
len(rma_list)
# Out:
# 194

# %%
# RMA LIST FROM TRANSFER
q = '''
        SELECT rma,[return] FROM transfers
        
        WHERE [return] IS NULL
    '''
try:
    rl = pd.read_sql(q,conn)
#     display(rl)
    for rma in rl['RMA']:
        rma_list.append(rma)
except Exception as e:
    print(e)
len(rma_list)

# RMA LIST FROM TRANSFER
q = '''
        SELECT rma,[return] FROM completed
        
        WHERE [return] IS NULL
    '''
try:
    rl = pd.read_sql(q,conn)
    display(rl)
    for rma in rl['RMA']:
        rma_list.append(rma)
except Exception as e:
    print(e)
len(rma_list)
# Out:
#                 RMA Return
# 0    FMSV2023070071   None
# 1    FMSV2023030069   None
# 2    FMSV2023030041   None
# 3    FMSV2023030040   None
# 4    FMSV2023040057   None
# ..              ...    ...
# 179  FMSV2022080064   None
# 180  FMSV2020090055   None
# 181  FMSV2019100025   None
# 182  FMSV2019100018   None
# 183  FMSV2019080079   None
#
# [184 rows x 2 columns]
# 378

# %%
rma_list

# %%
# exfm_web
q = f'''
        SELECT DISTINCT
            c.[rma no.] AS rma,c.customer_name AS customer,
            CASE
                WHEN e.location IS NULL THEN (SELECT e.location FROM consolidated c LEFT JOIN engineers e ON c.IN_INSPECT_USER_NAME = e.exfm_name)
                ELSE e.location END AS location,
            c.model AS model_d,c.serial_no AS sn,c.[Date Installed] AS install_date,
            c.[WARRANTY_END_DATE] AS warranty_date,
            c.[RECIEVE_DATE] AS receive_date,c.[IN_INSPECT_DATE] AS inspection_date,
            r.[start time] AS start_time,r.[end time] AS end_time,
            CASE
                WHEN c.[repair size] = 'Major' THEN 'Nặng'
                WHEN C.[repair size] = 'Minor' THEN 'Nhẹ'
                WHEN c.[repair size] IS NOT NULL THEN 'Khác' 
                ELSE c.[repair size] END AS repair_size,
            'Other' as issue_part,
            e.ks,c.[other id] AS wr_report,c.REPAIR_STATUS AS change_stt,c.approval,
            CASE
                WHEN c.approval  IN ('Decline','Cancel') THEN 'Chờ xác nhận (quá 3 tháng)'
                WHEN c.[create] < c.warranty_end_date AND c.repair_status ='Inspection' AND c.[other id] IS NULL THEN 'Chờ duyệt Bảo hành'
                WHEN c.[other id] IS NOT NULL AND c.repair_status ='Inspection' THEN 'Chuẩn bị linh kiện'
                ELSE s.vie_status END AS repair_status,
            CASE
            WHEN c.approval  IN ('Decline','Cancel') THEN 9
            ELSE s.stt_score END  AS e_score,
            CASE
                WHEN c.[other id] NOT NULL AND UPPER(c.[other id]) NOT LIKE '%REJECTED%' THEN 0.5
                ELSE 0 END AS w_score,
            
            c.[update time] AS update_time,c.Shipped as return_date

            FROM 
            ((consolidated c LEFT JOIN engineers e ON c.[update user] = e.exfm_code)
            LEFT JOIN status s ON c.[repair_status] = s.repair_status)
            LEFT JOIN repair_code r ON c.[rma no.] = r.[rma no.]
        WHERE c.[rma no.] IN {tuple(rma_list)}
    '''
try:
    exfm_web = pd.read_sql(q,conn)
    display(exfm_web)
except Exception as e:
    print(e)
exfm_web.to_sql('exfm_web',conn,index=False,if_exists = 'replace')
# Out:
#                 rma                            customer location      model_d  \
# 0    FMSV2019080079          FUJIFILM Vietnam Co., Ltd.     None     EC-530WI
# 1    FMSV2019100025                          FFAP asset     None    ED-530XT8
# 2    FMSV2019100018          FUJIFILM Vietnam Co., Ltd.     None    ED-530XT8
# 3    FMSV2020090055          FUJIFILM Vietnam Co., Ltd.     None     EG-530WR
# 4    FMSV2020110015  Bach Mai Hospital - Nagoya Project     None     EC-600WL
# ..              ...                                 ...      ...          ...
# 452  FMSV2023080077                   Bach Mai Hospital    Hanoi     EC-600WI
# 453  FMSV2023080078                   Bach Mai Hospital    Hanoi    EC-530WL3
# 454  FMSV2023080081                 FTYO - Loaner Asset    Hanoi      XL-4450
# 455  FMSV2023080089                  Bac Giang Hospital    Hanoi  EC-760R-V/I
# 456  FMSV2023080087          Quang Tri General Hospital      HCM     EG-530WR
#
#             sn         install_date        warranty_date  \
# 0    1C603K040  2017-08-30 00:00:00  2018-08-30 00:00:00
# 1    RD102A106  2019-06-07 00:00:00  2020-06-07 00:00:00
# 2    RD103A589  2012-09-17 00:00:00  2013-09-16 00:00:00
# 3    2G361K546  2019-03-20 00:00:00  2020-03-20 00:00:00
# 4    1C692K140  2014-10-11 00:00:00  2019-10-11 00:00:00
# ..         ...                  ...                  ...
# 452  6C692K197  2021-11-20 00:00:00  2022-11-20 00:00:00
# 453  1C643K192  2015-10-05 00:00:00  2016-10-05 00:00:00
# 454  1S094K191  2014-07-29 00:00:00                 None
# 455  7C728K102  2022-01-17 00:00:00  2023-01-17 00:00:00
# 456  JG361K198  2022-01-31 00:00:00  2023-01-31 00:00:00
#
#                    receive_date      inspection_date start_time  ...  \
# 0           2019-08-20 14:20:02  2019-08-22 08:31:23       None  ...
# 1           2019-10-18 14:47:56  2019-11-01 15:54:19       None  ...
# 2           2019-10-16 10:59:52  2020-07-13 09:56:13       None  ...
# 3           2020-09-25 13:37:27  2020-09-28 13:25:32       None  ...
# 4           2020-11-03 16:27:08  2020-11-10 14:20:32       None  ...
# ..                          ...                  ...        ...  ...
# 452         2023-08-21 17:22:34                 None       None  ...
# 453         2023-08-21 17:23:22                 None       None  ...
# 454  2023-08-21 17:26:30.908000                 None       None  ...
# 455         2023-08-23 19:01:50                 None       None  ...
# 456                        None                 None       None  ...
#
#     issue_part                 ks wr_report change_stt Approval  \
# 0        Other               None      None  Completed  Decline
# 1        Other               None      None  Completed   Cancel
# 2        Other               None      None  Completed   Cancel
# 3        Other               None      None  Completed   Cancel
# 4        Other               None      None  Completed   Cancel
# ..         ...                ...       ...        ...      ...
# 452      Other  Nguyễn Khắc Thắng      None    Receive     None
# 453      Other  Nguyễn Khắc Thắng      None    Receive     None
# 454      Other      Trần Minh Đức      None    Receive     None
# 455      Other        Lê Văn Hoàn      None    Receive     None
# 456      Other     Lê Quang Thông      None     Create     None
#
#                   repair_status e_score w_score                 update_time  \
# 0    Chờ xác nhận (quá 3 tháng)     9.0     0.0         2020-01-20 18:53:35
# 1    Chờ xác nhận (quá 3 tháng)     9.0     0.0         2020-03-13 19:09:23
# 2    Chờ xác nhận (quá 3 tháng)     9.0     0.0         2020-07-13 10:56:22
# 3    Chờ xác nhận (quá 3 tháng)     9.0     0.0         2021-01-11 11:32:37
# 4    Chờ xác nhận (quá 3 tháng)     9.0     0.0         2021-03-15 15:53:47
# ..                          ...     ...     ...                         ...
# 452               Đang Kiểm Tra     1.0     0.0  2023-08-24 13:38:59.116000
# 453               Đang Kiểm Tra     1.0     0.0  2023-08-24 13:38:13.396000
# 454               Đang Kiểm Tra     1.0     0.0  2023-08-21 17:26:30.908000
# 455               Đang Kiểm Tra     1.0     0.0  2023-08-24 19:16:27.733000
# 456                     Đã Nhận     0.0     0.0  2023-08-23 10:17:13.177000
#
#              return_date
# 0    2020-01-16 10:03:48
# 1    2020-03-06 09:12:28
# 2    2020-03-05 17:15:11
# 3    2021-01-06 16:13:44
# 4    2021-03-09 11:26:39
# ..                   ...
# 452                 None
# 453                 None
# 454                 None
# 455                 None
# 456                 None
#
# [457 rows x 22 columns]
# 457

# %%
# pending_file new_ml
q = '''
        SELECT DISTINCT 
            m.rma AS rma_id,m.customer,m.model,m.sn,d.dealer,scopes.vie AS type_s,
            STRFTIME('%Y-%m-%d',m.inspection) AS tr_date,
            STRFTIME('%Y-%m-%d',m.quotation) AS quotation_date,
            STRFTIME('%Y-%m-%d',m.confirmation) AS confirm_date,
            m.note as repair_note,m.status,status.vie_status as p_status,status.stt_score as p_score,
            m.return_date
            FROM ((new_ml m
                LEFT JOIN scopes ON m.model = scopes.model)
                LEFT JOIN status ON upper(m.status) = upper(status.repair_status))
                LEFT JOIN dealers d ON m.customer = d.customer
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
#              rma_id                           customer         model  \
# 0    FMSV2023020019         FUJIFILM Vietnam Co., Ltd.  EC-760ZP-V/M
# 1    FMSV2023020022                FTYO - Loaner Asset  EC-760ZP-V/M
# 2    FMSV2023020034                  Hoang Long Clinic   EC-760R-V/I
# 3    FMSV2023020050  Hanoi Medical University Hospital      EC-600WI
# 4    FMSV2023020067  Hanoi Medical University Hospital     VP-4450HD
# ..              ...                                ...           ...
# 189  FMSV2023080085         FUJIFILM Vietnam Co., Ltd.      EC-600WI
# 190  FMSV2023080086          Hung Viet Cancer Hospital       EG-760Z
# 191  FMSV2023080087         Quang Tri General Hospital      EG-530WR
# 192  FMSV2023080088       245 Clinic - Dr.Cuong Clinic     EC-250WL5
# 193  FMSV2023080089                 Bac Giang Hospital   EC-760R-V/I
#
#             sn     dealer             type_s     tr_date quotation_date  \
# 0    2C730K027       None  Ống soi đại tràng  2023-02-13           None
# 1    2C730K032       None  Ống soi đại tràng  2023-02-14           None
# 2    1C728K180  Trang Thi  Ống soi đại tràng  2023-02-23     2023-03-22
# 3    1C692K487  Trang Thi  Ống soi đại tràng  2023-02-21     2023-02-27
# 4    2V567K684  Trang Thi           Bộ Xử lý  2023-03-02     2023-03-15
# ..         ...        ...                ...         ...            ...
# 189  1C692K077       None  Ống soi đại tràng        None           None
# 190  8G403K185       None     Ống soi dạ dày  2023-08-23           None
# 191  JG361K198       None     Ống soi dạ dày        None           None
# 192  3C309K057       None  Ống soi đại tràng  2023-08-23     2023-08-23
# 193  7C728K102       None  Ống soi đại tràng        None           None
#
#     confirm_date              repair_note               status  \
# 0           None  Part OK: 14-Aug. #PO109   waiting for repair
# 1           None  Part OK: 14-Aug. #PO109   waiting for repair
# 2           None                    PO111     waiting for part
# 3     2023-02-27      Confirmed: 27-Feb.      Completed repair
# 4     2023-03-29                     None  LP/waiting for part
# ..           ...                      ...                  ...
# 189         None                     None             Received
# 190         None           Start: 23-Aug.         Under repair
# 191         None                     None             Received
# 192         None                     None      waiting confirm
# 193         None                     None             Received
#
#                p_status  p_score return_date
# 0                  None      NaN        None
# 1                  None      NaN        None
# 2    Chuẩn bị linh kiện      4.0        None
# 3     Hoàn tất sửa chữa      7.0        None
# 4    Chuẩn bị linh kiện      4.0        None
# ..                  ...      ...         ...
# 189             Đã Nhận      0.0        None
# 190       Đang sửa chữa      6.0        None
# 191             Đã Nhận      0.0        None
# 192        Chờ xác nhận      3.0        None
# 193             Đã Nhận      0.0        None
#
# [194 rows x 14 columns]

# %%
# pending_file transfer
q = '''
        SELECT DISTINCT
            rma,tf.customer,tf.model,sn,d.dealer,
            scopes.vie as type_s,
            STRFTIME('%Y-%m-%d',tf.tr_date) as tr_date,
            STRFTIME('%Y-%m-%d',tf.quotation_date) as quotation_date,
            STRFTIME('%Y-%m-%d',tf.confirmation) as confirm_date,
            tf.note as repair_note,
            CASE
            WHEN tf.clear IS NULL THEN 'transfer table'
            ELSE tf.clear END as status,
            CASE
                WHEN tf.return is null THEN
                (CASE
                    WHEN s.vie_status ="Chờ xác nhận" THEN "Chờ xác nhận (quá 3 tháng)"

                    ELSE s.vie_status END)
                ELSE 'Đã trả hàng (không sửa)' END AS p_status,
             CASE
                WHEN tf.return is null THEN	
                (CASE
                    WHEN s.stt_score = "3.0" THEN 9
                    ELSE s.stt_score END )
                ELSE 10 END AS p_score,
            (strftime('%Y-%m-%d',tf.return)) as return_date

            FROM ((transfers tf LEFT JOIN scopes ON tf.model = scopes.model)
                LEFT JOIN dealers d ON tf.customer = d.customer)
                LEFT JOIN status s ON upper(tf.old_status) = upper(s.repair_status)

            WHERE  RMA NOT NULL
            AND (strftime('%Y/%m/%d',tf.return) > strftime('%Y/%m/%d',date('now','-7 days'))
            OR tf.return IS NULL)
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
#                 RMA                                         customer  \
# 0    FMSV2023070071                                Bach Mai Hospital
# 1    FMSV2023030069                              Thong Nhat Hospital
# 2    FMSV2023030041  Hue University of Medicine and Pharmacy - Ginec
# 3    FMSV2023030040                                Viet Duc Hospital
# 4    FMSV2023030009                          Dong Thap Lung Hospital
# ..              ...                                              ...
# 184  FMSV2022080064                       FUJIFILM Vietnam Co., Ltd.
# 185  FMSV2020090055                       FUJIFILM Vietnam Co., Ltd.
# 186  FMSV2019100025                                       FFAP asset
# 187  FMSV2019100018                       FUJIFILM Vietnam Co., Ltd.
# 188  FMSV2019080079                       FUJIFILM Vietnam Co., Ltd.
#
#            model         sn     dealer                type_s     tr_date  \
# 0       EG-600WR  1G391K869  Trang Thi        Ống soi dạ dày        None
# 1      EC-720R/I  1C741K218  Trang Thi     Ống soi đại tràng  2023-03-28
# 2       EG-530WR  4G361A481        ETC        Ống soi dạ dày  2023-03-23
# 3    EC-760R-V/I  1C728K450       None     Ống soi đại tràng  2023-03-23
# 4        EB-530T  3B063A049       None  Ống soi khí phế quản  2023-03-07
# ..           ...        ...        ...                   ...         ...
# 184  EC-760R-V/I  2C728K079       None     Ống soi đại tràng        None
# 185     EG-530WR  2G361K546       None        Ống soi dạ dày        None
# 186    ED-530XT8  RD102A106       None       Ống soi mật tụy        None
# 187    ED-530XT8  RD103A589       None       Ống soi mật tụy        None
# 188     EC-530WI  1C603K040       None     Ống soi đại tràng        None
#
#     quotation_date confirm_date repair_note          status  \
# 0             None         None        None  transfer table
# 1       2023-03-29         None        None  transfer table
# 2       2023-04-14         None        None  transfer table
# 3       2023-03-30         None        None  transfer table
# 4       2023-03-14         None        None  transfer table
# ..             ...          ...         ...             ...
# 184           None         None        None  transfer table
# 185           None         None        None  transfer table
# 186           None         None        None  transfer table
# 187           None         None        None  transfer table
# 188           None         None        None  transfer table
#
#                        p_status  p_score return_date
# 0                          None      NaN        None
# 1    Chờ xác nhận (quá 3 tháng)      9.0        None
# 2    Chờ xác nhận (quá 3 tháng)      9.0        None
# 3    Chờ xác nhận (quá 3 tháng)      9.0        None
# 4       Đã trả hàng (không sửa)     10.0  2023-08-23
# ..                          ...      ...         ...
# 184                        None      NaN        None
# 185                        None      NaN        None
# 186                        None      NaN        None
# 187                        None      NaN        None
# 188                        None      NaN        None
#
# [189 rows x 14 columns]

# %%
# pending_file completed
q = '''
        SELECT DISTINCT
            rma,tf.customer,tf.model,sn,d.dealer,
            scopes.vie as type_s,
            STRFTIME('%Y-%m-%d',tf.quotation_date) as tr_date,
            STRFTIME('%Y-%m-%d',tf.quotation_date) as quotation_date,
            STRFTIME('%Y-%m-%d',tf.confirmation) as confirm_date,
            tf.note as repair_note,
            CASE
            WHEN tf.clear IS NULL THEN 'complete table'
            ELSE tf.clear END as status,
            CASE
                WHEN tf.return is null THEN 'Đang giao hàng'
                ELSE 'Hoàn tất giao hàng' END AS p_status,
            CASE
                WHEN tf.return is null THEN 7
                ELSE 8 END AS p_score,
            (strftime('%Y-%m-%d',tf.return)) as return_date

            FROM (completed tf LEFT JOIN scopes ON tf.model = scopes.model)
                LEFT JOIN dealers d ON tf.customer = d.customer
            WHERE  RMA NOT NULL
            AND (strftime('%Y/%m/%d',tf.return) > strftime('%Y/%m/%d',date('now','-7 days'))
            OR tf.return IS NULL)
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
#                RMA                           customer         model  \
# 0   FMSV2023060066         FUJIFILM Vietnam Co., Ltd.       EG-760R
# 1   FMSV2023080005           Phu Tho General Hospital     EC-530WL3
# 2   FMSV2023080037                FTYO - Loaner Asset     ED-530XT8
# 3   FMSV2023080040                Friendship Hospital      EC-600WI
# 4   FMSV2023080046         FUJIFILM Vietnam Co., Ltd.  EC-760ZP-V/M
# ..             ...                                ...           ...
# 77  FMSV2022070004  Hanoi Medical University Hospital      EC-600WI
# 78  FMSV2022060056  Hanoi Medical University Hospital      EG-600WR
# 79  FMSV2022060072  Hanoi Medical University Hospital      EC-600WI
# 80  FMSV2022060029  Hanoi Medical University Hospital      EC-600WI
# 81  FMSV2022050018           Mediplus Clinic - Ha Noi  EC-760ZP-V/M
#
#            sn     dealer             type_s     tr_date quotation_date  \
# 0   2G402K099       None     Ống soi dạ dày        None           None
# 1   JC643K007       None  Ống soi đại tràng        None           None
# 2   3D103L052       None    Ống soi mật tụy        None           None
# 3   1C692K178       None  Ống soi đại tràng        None           None
# 4   2C730K026       None  Ống soi đại tràng        None           None
# ..        ...        ...                ...         ...            ...
# 77  5C692K028  Trang Thi  Ống soi đại tràng        None           None
# 78  2G391K085  Trang Thi     Ống soi dạ dày        None           None
# 79  1C692K733  Trang Thi  Ống soi đại tràng        None           None
# 80  3C692K098  Trang Thi  Ống soi đại tràng  2022-06-16     2022-06-16
# 81  5C730K016       None  Ống soi đại tràng        None           None
#
#    confirm_date                                      repair_note  \
# 0          None                                   Start: 10-Aug.
# 1          None                                     End: 16-Aug.
# 2          None                                             None
# 3          None                                             None
# 4          None                       End: 18-Aug.Start: 15-Aug.
# ..          ...                                              ...
# 77         None                                             None
# 78         None                                             None
# 79         None                                             None
# 80         None  1. Less than 4 weeks after giving the quotation
# 81         None                                             None
#
#             status        p_status  p_score return_date
# 0   complete table  Đang giao hàng        7        None
# 1   complete table  Đang giao hàng        7        None
# 2   complete table  Đang giao hàng        7        None
# 3   complete table  Đang giao hàng        7        None
# 4   complete table  Đang giao hàng        7        None
# ..             ...             ...      ...         ...
# 77  complete table  Đang giao hàng        7        None
# 78  complete table  Đang giao hàng        7        None
# 79  complete table  Đang giao hàng        7        None
# 80  complete table  Đang giao hàng        7        None
# 81  complete table  Đang giao hàng        7        None
#
# [82 rows x 14 columns]

# %%
#new job 
q = '''
        SELECT DISTINCT rma as rma_id,ew.customer,model_d as model,sn,d.dealer,
            s.vie,strftime('%Y-%m-%d',inspection_date) as tr_date,
            CASE
            WHEN rma IS NULL THEN NULL
            ELSE NULL END AS quotation_date,
            CASE
            WHEN rma IS NULL THEN NULL
            ELSE NULL END AS confirm_date,
            CASE
            WHEN rma IS NULL THEN NULL
            ELSE NULL END AS note,
            change_stt as status,st.vie_status as p_status,st.stt_score as p_score,(strftime('%Y-%m-%d',ew.return_date)) as return_date


            FROM ((exfm_web ew
            LEFT JOIN dealers d ON d.customer = ew.customer)
            LEFT JOIN scopes s ON s.model = ew.model_d)
            LEFT JOIN status st ON st.repair_status = ew.change_stt

            WHERE rma > (SELECT max(rma) FROM new_ml)
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
# Empty DataFrame
# Columns: [rma_id, customer, model, sn, dealer, Vie, tr_date, quotation_date, confirm_date, note, status, p_status, p_score, return_date]
# Index: []

# %%
# pending file total
q = '''
        SELECT DISTINCT 
            m.rma AS rma_id,m.customer,m.model,m.sn,d.dealer,scopes.vie AS type_s,
            STRFTIME('%Y-%m-%d',m.inspection) AS tr_date,
            STRFTIME('%Y-%m-%d',m.quotation) AS quotation_date,
            STRFTIME('%Y-%m-%d',m.confirmation) AS confirm_date,
            m.note as repair_note,m.status,status.vie_status as p_status,status.stt_score as p_score,
            m.return_date
            FROM ((new_ml m
                LEFT JOIN scopes ON m.model = scopes.model)
                LEFT JOIN status ON upper(m.status) = upper(status.repair_status))
                LEFT JOIN dealers d ON m.customer = d.customer
        UNION ALL
            SELECT DISTINCT
            rma,tf.customer,tf.model,sn,d.dealer,
            scopes.vie as type_s,
            STRFTIME('%Y-%m-%d',tf.tr_date) as tr_date,
            STRFTIME('%Y-%m-%d',tf.quotation_date) as quotation_date,
            STRFTIME('%Y-%m-%d',tf.confirmation) as confirm_date,
            tf.note as repair_note,
            CASE
            WHEN tf.clear IS NULL THEN 'transfer table'
            ELSE tf.clear END as status,
            CASE
                WHEN tf.return is null THEN
                (CASE
                    WHEN s.vie_status ="Chờ xác nhận" THEN "Chờ xác nhận (quá 3 tháng)"

                    ELSE s.vie_status END)
                ELSE 'Đã trả hàng (không sửa)' END AS p_status,
             CASE
                WHEN tf.return is null THEN	
                (CASE
                    WHEN s.stt_score = "3.0" THEN 9
                    ELSE s.stt_score END )
                ELSE 10 END AS p_score,
            (strftime('%Y-%m-%d',tf.return)) as return_date

            FROM ((transfers tf LEFT JOIN scopes ON tf.model = scopes.model)
                LEFT JOIN dealers d ON tf.customer = d.customer)
                LEFT JOIN status s ON upper(tf.old_status) = upper(s.repair_status)

            WHERE  RMA NOT NULL
            AND (strftime('%Y/%m/%d',tf.return) > strftime('%Y/%m/%d',date('now','-7 days'))
            OR tf.return IS NULL)
        
        UNION ALL
             SELECT DISTINCT
            rma,tf.customer,tf.model,sn,d.dealer,
            scopes.vie as type_s,
            STRFTIME('%Y-%m-%d',tf.quotation_date) as tr_date,
            STRFTIME('%Y-%m-%d',tf.quotation_date) as quotation_date,
            STRFTIME('%Y-%m-%d',tf.confirmation) as confirm_date,
            tf.note as repair_note,
            CASE
            WHEN tf.clear IS NULL THEN 'complete table'
            ELSE tf.clear END as status,
            CASE
                WHEN tf.return is null THEN 'Đang giao hàng'
                ELSE 'Hoàn tất giao hàng' END AS p_status,
            CASE
                WHEN tf.return is null THEN 7
                ELSE 8 END AS p_score,
            (strftime('%Y-%m-%d',tf.return)) as return_date

            FROM (completed tf LEFT JOIN scopes ON tf.model = scopes.model)
                LEFT JOIN dealers d ON tf.customer = d.customer
            WHERE  RMA NOT NULL
            AND (strftime('%Y/%m/%d',tf.return) > strftime('%Y/%m/%d',date('now','-7 days'))
            OR tf.return IS NULL)
        UNION ALL
            SELECT DISTINCT rma as rma_id,ew.customer,model_d as model,sn,d.dealer,
            s.vie,strftime('%Y-%m-%d',inspection_date) as tr_date,
            CASE
            WHEN rma IS NULL THEN NULL
            ELSE NULL END AS quotation_date,
            CASE
            WHEN rma IS NULL THEN NULL
            ELSE NULL END AS confirm_date,
            CASE
            WHEN rma IS NULL THEN NULL
            ELSE NULL END AS note,
            change_stt as status,st.vie_status as p_status,st.stt_score as p_score,(strftime('%Y-%m-%d',ew.return_date)) as return_date


            FROM ((exfm_web ew
            LEFT JOIN dealers d ON d.customer = ew.customer)
            LEFT JOIN scopes s ON s.model = ew.model_d)
            LEFT JOIN status st ON st.repair_status = ew.change_stt

            WHERE rma > (SELECT max(rma) FROM new_ml)
    '''
try:
    pending_file = pd.read_sql(q,conn)
    display(pending_file)
    
except Exception as e:
    print(e)
# Out:
#              rma_id                           customer         model  \
# 0    FMSV2023020019         FUJIFILM Vietnam Co., Ltd.  EC-760ZP-V/M
# 1    FMSV2023020022                FTYO - Loaner Asset  EC-760ZP-V/M
# 2    FMSV2023020034                  Hoang Long Clinic   EC-760R-V/I
# 3    FMSV2023020050  Hanoi Medical University Hospital      EC-600WI
# 4    FMSV2023020067  Hanoi Medical University Hospital     VP-4450HD
# ..              ...                                ...           ...
# 460  FMSV2022070004  Hanoi Medical University Hospital      EC-600WI
# 461  FMSV2022060056  Hanoi Medical University Hospital      EG-600WR
# 462  FMSV2022060072  Hanoi Medical University Hospital      EC-600WI
# 463  FMSV2022060029  Hanoi Medical University Hospital      EC-600WI
# 464  FMSV2022050018           Mediplus Clinic - Ha Noi  EC-760ZP-V/M
#
#             sn     dealer             type_s     tr_date quotation_date  \
# 0    2C730K027       None  Ống soi đại tràng  2023-02-13           None
# 1    2C730K032       None  Ống soi đại tràng  2023-02-14           None
# 2    1C728K180  Trang Thi  Ống soi đại tràng  2023-02-23     2023-03-22
# 3    1C692K487  Trang Thi  Ống soi đại tràng  2023-02-21     2023-02-27
# 4    2V567K684  Trang Thi           Bộ Xử lý  2023-03-02     2023-03-15
# ..         ...        ...                ...         ...            ...
# 460  5C692K028  Trang Thi  Ống soi đại tràng        None           None
# 461  2G391K085  Trang Thi     Ống soi dạ dày        None           None
# 462  1C692K733  Trang Thi  Ống soi đại tràng        None           None
# 463  3C692K098  Trang Thi  Ống soi đại tràng  2022-06-16     2022-06-16
# 464  5C730K016       None  Ống soi đại tràng        None           None
#
#     confirm_date                                      repair_note  \
# 0           None                          Part OK: 14-Aug. #PO109
# 1           None                          Part OK: 14-Aug. #PO109
# 2           None                                            PO111
# 3     2023-02-27                              Confirmed: 27-Feb.
# 4     2023-03-29                                             None
# ..           ...                                              ...
# 460         None                                             None
# 461         None                                             None
# 462         None                                             None
# 463         None  1. Less than 4 weeks after giving the quotation
# 464         None                                             None
#
#                   status            p_status  p_score return_date
# 0     waiting for repair                None      NaN        None
# 1     waiting for repair                None      NaN        None
# 2       waiting for part  Chuẩn bị linh kiện      4.0        None
# 3       Completed repair   Hoàn tất sửa chữa      7.0        None
# 4    LP/waiting for part  Chuẩn bị linh kiện      4.0        None
# ..                   ...                 ...      ...         ...
# 460       complete table      Đang giao hàng      7.0        None
# 461       complete table      Đang giao hàng      7.0        None
# 462       complete table      Đang giao hàng      7.0        None
# 463       complete table      Đang giao hàng      7.0        None
# 464       complete table      Đang giao hàng      7.0        None
#
# [465 rows x 14 columns]

# %%
today = dt.now().strftime('%y%m%d')
pending_name = f'pending_{today}.xls'
pending_file.to_excel(f'New ML/{pending_name}',index = False)
# Out:
# C:\Users\quang\AppData\Local\Temp\ipykernel_12036\3554018105.py:3: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   pending_file.to_excel(f'New ML/{pending_name}',index = False)

# %%
# Out:
# '230825'

# %%
# part_name
q = f'''
        SELECT 
            DISTINCT p.[RMA No.] AS rma,p.PART_NO AS part_no,
            p.Part_description AS part_description,pn.vie as vie_name
            FROM parts p
            LEFT JOIN part_name pn ON p.part_description = pn.part_description

            WHERE rma IN {tuple(rma_list)}
        ORDER BY rma
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
#                  rma       part_no               part_description  \
# 0     FMSV2019080079  343A1295408G  LG FLEXIBLE SECTION ASSY ROHS
# 1     FMSV2019080079  342A1318071B                      BSA-C287A
# 2     FMSV2019080079   68B12078100            RUBBER FOR BSA ROHS
# 3     FMSV2019080079    54A3792370                  NUT ASSY ROHS
# 4     FMSV2019080079    42B593410A                    SLEEVE ROHS
# ...              ...           ...                            ...
# 3044  FMSV2023080088   370Y200590_                 AW TUBE ASS''Y
# 3045  FMSV2023080088   68B12952250                 WATER JET TUBE
# 3046  FMSV2023080088    54A379237A                      NUT ASS'Y
# 3047  FMSV2023080088    42B593410A                    PIPE SLEEVE
# 3048  FMSV2023080088   56A1082711A                      WIRE ASSY
#
#               vie_name
# 0           Vỏ ống dẫn
# 1     Bộ phận uốn cong
# 2            Vỏ cao su
# 3        Đai ốc (đồng)
# 4       Ống nối (đồng)
# ...                ...
# 3044     Kênh khí nước
# 3045     Kênh nước phụ
# 3046     Đai ốc (đồng)
# 3047    Ống nối (đồng)
# 3048    Dây cáp (thép)
#
# [3049 rows x 4 columns]

# %%
# r_code
q = '''
        SELECT r.[rma no.] as rma,pf.r_code as r_code,pf.r_description as r_description,pf.vie_name

        FROM r_code pf
        LEFT JOIN repair_code r ON pf.r_code = r.r_code
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
#                  rma r_code                       r_description  \
# 0     FMSV2019080096   R001                ANGL.Replace LR Knob
# 1     FMSV2019090030   R001                ANGL.Replace LR Knob
# 2     FMSV2020060050   R001                ANGL.Replace LR Knob
# 3     FMSV2020080043   R001                ANGL.Replace LR Knob
# 4     FMSV2020090057   R001                ANGL.Replace LR Knob
# ...              ...    ...                                 ...
# 8995  FMSV2023070054   R006    AWB.Replace O-Ring/One Way Valve
# 8996  FMSV2023050042   R322  PCB. Replace Main CPU PCB Assembly
# 8997  FMSV2021030007   R263                    FUS.Replace Fuse
# 8998  FMSV2023050081   R263                    FUS.Replace Fuse
# 8999  FMSV2023060058   R254             PCB.Replace Network PCB
#
#                         vie_name
# 0             Bộ phận điều khiển
# 1             Bộ phận điều khiển
# 2             Bộ phận điều khiển
# 3             Bộ phận điều khiển
# 4             Bộ phận điều khiển
# ...                          ...
# 8995                 Vòng cao su
# 8996      Thay thế bo mạch chính
# 8997                Thay cầu chì
# 8998                Thay cầu chì
# 8999  Thay thế bo mạch giao tiếp
#
# [9000 rows x 4 columns]

# %%
# exfm_web
q = '''
        SELECT * FROM r_code
    '''
try:
    display(pd.read_sql(q,conn))
except Exception as e:
    print(e)
# Out:
#     R_CODE                              R_DESCRIPTION  \
# 0     R001                       ANGL.Replace LR Knob
# 1     R002                 ANGL. Replace LR Lock Knob
# 2     R003                      ANGL. Replace UD Knob
# 3     R004                  ANGL.Replace UD Lock Knob
# 4     R005  ANGL. Repair Angle Knob Mechanism Section
# ..     ...                                        ...
# 188   R772                      ULT. Replace ISA（740)
# 189   R006           AWB.Replace O-Ring/One Way Valve
# 190   R322         PCB. Replace Main CPU PCB Assembly
# 191   R263                           FUS.Replace Fuse
# 192   R254                    PCB.Replace Network PCB
#
#                        vie_name    COD  GROUP  time               update
# 0            Bộ phận điều khiển  ANGL.   18.0   4.0  2021-10-01 00:00:00
# 1            Bộ phận điều khiển  ANGL.   18.0   4.0  2021-10-01 00:00:00
# 2            Bộ phận điều khiển  ANGL.   18.0   4.0  2021-10-01 00:00:00
# 3            Bộ phận điều khiển  ANGL.   18.0   4.0  2021-10-01 00:00:00
# 4            Bộ phận điều khiển  ANGL.   18.0   4.0  2021-10-01 00:00:00
# ..                          ...    ...    ...   ...                  ...
# 188          Thân ống soi (ISA)   None    NaN   NaN                 None
# 189                 Vòng cao su   None    NaN   NaN                 None
# 190      Thay thế bo mạch chính   None    NaN   NaN                 None
# 191                Thay cầu chì   None    NaN   NaN                 None
# 192  Thay thế bo mạch giao tiếp   None    NaN   NaN                 None
#
# [193 rows x 7 columns]
