# %%
from langchain.chat_models import ChatOpenAI
from langchain.agents import create_pandas_dataframe_agent

# %%
import pandas as pd
from sqlite3 import connect

# %%
conn = connect('quotation.db')

# %%
open_api_key = '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'

# %%
ml = pd.read_sql('select * from new_ml',conn)
ml
# Out:
#     No             rma    cus_type                           customer  \
# 0    1  FMSV2023020019    FF asset         FUJIFILM Vietnam Co., Ltd.
# 1    2  FMSV2023020022    FF asset                FTYO - Loaner Asset
# 2    2  FMSV2023030060     Private                  Hoang Long Clinic
# 3    3  FMSV2023030075    FF asset         FUJIFILM Vietnam Co., Ltd.
# 4    4  FMSV2023040004    FF asset                FTYO - Loaner Asset
# ..  ..             ...         ...                                ...
# 82  18  FMSV2023090022    FF asset         FUJIFILM Vietnam Co., Ltd.
# 83  18  FMSV2023090025  Government  Hanoi Medical University Hospital
# 84  19  FMSV2023090026    FF asset         FUJIFILM Vietnam Co., Ltd.
# 85  19  FMSV2023090027  Government      Nga Bay City General Hospital
# 86  20  FMSV2023090028    FF asset         FUJIFILM Vietnam Co., Ltd.
#
#        dealer location       installed_date         model         sn  \
# ...

# %%
chat = ChatOpenAI(openai_api_key = open_api_key,engine="text-davinci-003",temperature = 0.0)
agent = create_pandas_dataframe_agent(chat,ml)
# Out:
# WARNING! engine is not default parameter.
#                     engine was transferred to model_kwargs.
#                     Please confirm that engine is what you intended.

# %%
agent.run("Which items were received in last week?")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 agent.run("Which items were received in last week?")
#
# File ~\anaconda3\lib\site-packages\langchain\chains\base.py:487, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     485     if len(args) != 1:
#     486         raise ValueError("`run` supports only one positional argument.")
# --> 487     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     488         _output_key
#     489     ]
#     491 if kwargs and not args:
#     492     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     493         _output_key
#     494     ]
#
# File ~\anaconda3\lib\site-packages\langchain\chains\base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
# ...
