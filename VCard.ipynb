# %%
# !pip install vobject

# %%
import vobject
import qrcode
from PIL import Image

def create_qr_image(link,name,logo_link='',box_size=20,border = 1,image_folder='images'):
#     Logo_link = 'files\\Fujifilm10nam2.png'

    if logo_link !='':
    
        logo = Image.open(logo_link)

        # taking base width
        basewidth = 350

        # adjust image size
        wpercent = (basewidth/float(logo.size[0]))
        hsize = int((float(logo.size[1])*float(wpercent)))
        logo = logo.resize((basewidth, hsize), Image.ANTIALIAS)
        
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_H,
        box_size=box_size,
        border=border,
    )
    qr.add_data(link)
    qr.make(fit=True)
    img = qr.make_image(fill_color="black", back_color="white").convert('RGB')
    if logo_link !='':
        pos = ((img.size[0] - logo.size[0]) // 2,
               (img.size[1] - logo.size[1]) // 2)
        img.paste(logo, pos)
    img.save(f"{image_folder}\\{name}.png")

if __name__ == "__main__":
    # Example data
    name = "Fujifilm Vietnam \nCustomer Service Center - Endoscope"
    email = "ffvn-endo-cs@fujifilm.com"
    phone = "1800 646830"
    website = "https://noisoifujifilm.vn"

    # Create vCard
    create_vcard(name, email, phone, website)

    # Read vCard data
    with open('my_contact.vcf', 'r') as f:
        vcard_data = f.read()

    # Generate QR code
#     generate_qr_code(vcard_data, output_file='my_qrcode.png')
    logo_link = 'logo/FF_logo_border.png'
    create_qr_image(vcard_data,'ffvn',logo_link,box_size=10)
# Out:
# C:\Users\quang\AppData\Local\Temp\ipykernel_5736\1102901675.py:18: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   logo = logo.resize((basewidth, hsize), Image.ANTIALIAS)

# %%
# Example data
name = "Fujifilm Vietnam \nCustomer Service Center - Endoscope"
email = "ffvn-endo-cs@fujiflm.com"
phone = "1800 646830"
website = "https://noisoifujifilm.vn"
logo_path = 'logo\FF_logo_border.png'

# %%
import vobject
import qrcode
from PIL import Image

def create_vcard(name, email, phone, website):
    # Create a vCard
    vcard = vobject.vCard()

    # Add the Name
    vcard.add('fn').value = name

    # Add the Email
    vcard.add('email').value = email

    # Add the Phone
    vcard.add('tel').value = phone

    # Add the Website
    vcard.add('url').value = website

    # Save the vCard to a file
    with open('my_contact.vcf', 'w') as f:
        f.write(vcard.serialize())

def generate_qr_code(vcard_data, output_file='qrcode.png'):
    # Generate QR code
    qr = qrcode.QRCode(
        version=1,
        error_correction=qrcode.constants.ERROR_CORRECT_L,
        box_size=10,
        border=1,
    )
    qr.add_data(vcard_data)
    qr.make(fit=True)

    # Create an image from the QR code
    img = qr.make_image(fill_color="black", back_color="white")

    # Save the image to a file
    img.save(output_file)

if __name__ == "__main__":
    # Example data
#     name = "John Doe"
#     email = "john.doe@example.com"
#     phone = "+1234567890"
#     website = "https://www.example.com"

    # Create vCard
    create_vcard(name, email, phone, website)

    # Read vCard data
    with open('my_contact.vcf', 'r') as f:
        vcard_data = f.read()

    # Generate QR code
    generate_qr_code(vcard_data, output_file='images/without_logo.png')
